# %% [markdown]
# # Imports

# %%
 config = {
    'gdt': {
        'depth': 10,
        
        'learning_rate_index': 0.05,
        'learning_rate_values': 0.01,
        'learning_rate_leaf': 0.005,
        
        'split_index_activation': 'entmax',
                
        'optimizer': 'SWA', #adam with stochastic weight averaging
        
        'initializer': 'GlorotUniform', 
        
        'dropout': 0,
        
        'prunePostHoc': True,
        'prune_threshold': 1,
        
        'batch_size': 128,#512,
        'epochs': 10_000,
        
        'loss': 'binary_crossentropy', #binary_focal_crossentropy, binary_crossentropy
        
        'focalLossGamma': 3,
        
        'polyLoss': False,
        'polyLossEpsilon': 2,
        
        'restarts': 3,
        'restart_type': 'loss', #'loss', 'metric'
        
        'early_stopping_epochs': 200,
        'early_stopping_type': 'loss', #'loss', 'metric'
        'early_stopping_epsilon': 0.0,
    },
    
    'preprocessing': {
        'balance_threshold': 0.25,#.25, #if minclass fraction less than threshold/num_classes-1 | #0=no rebalance, 1=rebalance all
        'normalization_technique': 'quantile', #'min-max'
        'quantile_noise': 1e-3,
    },

    'computation': {
        'random_seed': 42,
        'trials': 10,
        
        'use_best_hpo_result': True,
        'hpo_path': '_HPO',
        
        'force_depth': False,
        'force_dropout': False,
        'force_restart': True,   
        
        'use_gpu': True,
        'gpu_numbers': '0',#'1',
        'n_jobs': 10,
        'verbosity': 0,
        
        'hpo': None,
        'search_iterations': 300,
        'cv_num': 3,     
        
        'metrics_class': ['f1', 'roc_auc', 'accuracy', 'total_nodes','internal_node_num', 'leaf_node_num'],      
        'eval_metric_class': ['f1', 'roc_auc', 'accuracy', 'total_nodes', 'internal_node_num', 'leaf_node_num'], #f1 accuracy
    },
    
    'benchmarks': {
        'DNDT': True,
        'GeneticTree': True,
        'DL85': True,
        
        'sklearn': True,
        
        'NeuralNetwork': False,
    }
}

# %%
import numpy as np
np.set_printoptions(suppress=True)

import sklearn
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split, ParameterGrid, ParameterSampler, GridSearchCV, RandomizedSearchCV, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier, plot_tree, DecisionTreeRegressor
from sklearn.metrics import accuracy_score, f1_score, make_scorer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, LabelEncoder, OrdinalEncoder
from pydl85 import DL85Classifier

from livelossplot import PlotLosses

import os
from tqdm.notebook import tqdm
from matplotlib import pyplot as plt

from IPython.display import Image
from IPython.display import display, clear_output

import pandas as pd

if config['computation']['use_gpu']:
    os.environ['CUDA_VISIBLE_DEVICES'] = str(config['computation']['gpu_numbers'])
    os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
    os.environ['XLA_FLAGS'] = "--xla_gpu_cuda_data_dir=/usr/local/cuda-11.6"
    os.environ['TF_XLA_FLAGS'] = "--tf_xla_enable_xla_devices --tf_xla_auto_jit=2"    
else:
    os.environ['CUDA_VISIBLE_DEVICES'] = ''
    os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'false' 
#os.environ['TF_XLA_FLAGS'] = "--tf_xla_auto_jit=2 --tf_xla_cpu_global_jit" 


import warnings
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
os.environ["PYTHONWARNINGS"] = "ignore"
import logging

import tensorflow as tf
import tensorflow_addons as tfa

tf.get_logger().setLevel('ERROR')
tf.autograph.set_verbosity(3)

np.seterr(all="ignore")

from keras import backend as K

import seaborn as sns
sns.set_style("darkgrid")

import time
import random

from utilities.utilities_GDT import *
from utilities.GDT import *
from utilities.DNDT import *

from joblib import Parallel, delayed

from itertools import product
from collections.abc import Iterable

from copy import deepcopy
from pathlib import Path
import pickle
import dill

tf.random.set_seed(config['computation']['random_seed'])
np.random.seed(config['computation']['random_seed'])
random.seed(config['computation']['random_seed'])
tf.keras.utils.set_random_seed(config['computation']['random_seed'])

from datetime import datetime
timestr = datetime.utcnow().strftime('%Y-%m-%d--%H-%M-%S%f')
print(timestr)
os.makedirs(os.path.dirname("./evaluation_results" + config['computation']['hpo_path'] + "/latex_tables/" + timestr +"/"), exist_ok=True)

filepath = './evaluation_results' + config['computation']['hpo_path'] + '/depth' + str(config['gdt']['depth']) + '/' + timestr + '/'
Path(filepath).mkdir(parents=True, exist_ok=True)    

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

from joblib.externals.loky import set_loky_pickler
set_loky_pickler("dill")
# Out:
# 2023-04-28--13-21-16262813

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print("Num XLA-GPUs Available: ", len(tf.config.experimental.list_physical_devices('XLA_GPU')))
# Out:
# Num GPUs Available:  1
# Num XLA-GPUs Available:  1

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Real-World Eval

# %% [markdown]
# ### Classification

# %%
identifier_list_classification_binary = [
                        'BIN:Blood Transfusion',# 748 4
                        'BIN:Banknote Authentication',# 1372 4
                        'BIN:Titanic',# 891 7 
                        'BIN:Raisins',#900 7
                        'BIN:Rice',#3810 7
                        'BIN:Echocardiogram',#132 8 ###TD
                        'BIN:Wisconsin Diagnostic Breast Cancer',# 569 10
                        'BIN:Loan House',# 614 11
                        'BIN:Heart Failure',# 299 12
                        'BIN:Heart Disease',# 303 13
                        'BIN:Adult',# 32561 14
                        'BIN:Bank Marketing',# 45211 14
                        'BIN:Congressional Voting',# 435, 16 ###TD
                        'BIN:Absenteeism',# 740 18
                        'BIN:Hepatitis',#155 19 ###TD
                        'BIN:German',# 1000 20
                        'BIN:Mushroom',#8124 22
                        'BIN:Credit Card',# 30000 23
                        'BIN:Horse Colic',#368 27
                        'BIN:Thyroid',#9172 29 ###TD
                        'BIN:Cervical Cancer',# 858 15
                        'BIN:Spambase',# 4601 57
                  ]

# %%
benchmark_dict = get_benchmark_dict(config=config, eval_identifier='classification') 

parallel_eval_real_world = Parallel(n_jobs=min(config['computation']['n_jobs'], config['computation']['trials']), verbose=3, backend='loky') #loky #sequential multiprocessing
evaluation_results_real_world_classification_binary = parallel_eval_real_world(delayed(evaluate_real_world_parallel_nested)(identifier_list=identifier_list_classification_binary[::-1], 
                                                                                                                           random_seed_data=config['computation']['random_seed']+i,
                                                                                                                           random_seed_model=config['computation']['random_seed'],
                                                                                                                           config = config,
                                                                                                                           benchmark_dict = benchmark_dict,
                                                                                                                           metrics = config['computation']['metrics_class'],
                                                                                                                           verbosity = -1) for i in range(config['computation']['trials']))
# Out:
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  6.4min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  6.8min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  6.9min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  7.1min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  7.4min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  7.4min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  7.7min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  7.7min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  8.1min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  8.1min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  8.5min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  8.9min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  9.1min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  9.2min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  9.6min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  9.7min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  9.8min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 10.1min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 10.1min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 10.2min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 202.6min finished
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 204.8min finished
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 205.3min finished
# [Parallel(n_jobs=10)]: Done   3 out of  10 | elapsed: 205.4min remaining: 479.4min
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 206.7min finished
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 207.1min finished
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 209.2min finished
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 213.1min finished
# [Parallel(n_jobs=10)]: Done   7 out of  10 | elapsed: 213.3min remaining: 91.4min
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 223.9min finished
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 224.0min finished
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 225.5min finished
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed: 225.7min finished

# %%
plot_table_save_results(benchmark_dict=benchmark_dict,
                        evaluation_results_real_world=evaluation_results_real_world_classification_binary,
                        identifier_list=identifier_list_classification_binary,                            
                        identifier_string='binary_test',
                        filepath=filepath,
                        config=config)      

plot_table_save_results(benchmark_dict=benchmark_dict,
                        evaluation_results_real_world=evaluation_results_real_world_classification_binary,
                        identifier_list=identifier_list_classification_binary,                            
                        identifier_string='binary_valid',
                        filepath=filepath,
                        config=config)  

plot_table_save_results(benchmark_dict=benchmark_dict,
                        evaluation_results_real_world=evaluation_results_real_world_classification_binary,
                        identifier_list=identifier_list_classification_binary,                            
                        identifier_string='binary_train',
                        filepath=filepath,
                        config=config)
# Out:
# <style type="text/css">
# #T_33fd3_row0_col0, #T_33fd3_row1_col0, #T_33fd3_row2_col0, #T_33fd3_row3_col4, #T_33fd3_row4_col8, #T_33fd3_row5_col0, #T_33fd3_row6_col2, #T_33fd3_row7_col0, #T_33fd3_row8_col8, #T_33fd3_row9_col0, #T_33fd3_row10_col8, #T_33fd3_row11_col0, #T_33fd3_row12_col0, #T_33fd3_row13_col0, #T_33fd3_row14_col8, #T_33fd3_row15_col0, #T_33fd3_row16_col0, #T_33fd3_row17_col4, #T_33fd3_row18_col0, #T_33fd3_row19_col8, #T_33fd3_row20_col0, #T_33fd3_row21_col8, #T_33fd3_row24_col0 {
#   background-color: #9CC95C;
# }
# #T_33fd3_row0_col2, #T_33fd3_row1_col2, #T_33fd3_row2_col2, #T_33fd3_row3_col2, #T_33fd3_row4_col2, #T_33fd3_row5_col8, #T_33fd3_row6_col8, #T_33fd3_row7_col4, #T_33fd3_row8_col6, #T_33fd3_row9_col4, #T_33fd3_row10_col4, #T_33fd3_row11_col4, #T_33fd3_row12_col6, #T_33fd3_row13_col4, #T_33fd3_row14_col4, #T_33fd3_row15_col4, #T_33fd3_row16_col4, #T_33fd3_row17_col0, #T_33fd3_row18_col4, #T_33fd3_row19_col4, #T_33fd3_row20_col6, #T_33fd3_row21_col6, #T_33fd3_row24_col6 {
#   background-color: #FF6961;
# }
# </style>
# <table id="T_33fd3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33fd3_level0_col0" class="col_heading level0 col0" >GDT f1_mean</th>
#       <th id="T_33fd3_level0_col1" class="col_heading level0 col1" >GDT f1_std</th>
#       <th id="T_33fd3_level0_col2" class="col_heading level0 col2" >DNDT f1_mean</th>
#       <th id="T_33fd3_level0_col3" class="col_heading level0 col3" >DNDT f1_std</th>
#       <th id="T_33fd3_level0_col4" class="col_heading level0 col4" >GeneticTree f1_mean</th>
#       <th id="T_33fd3_level0_col5" class="col_heading level0 col5" >GeneticTree f1_std</th>
#       <th id="T_33fd3_level0_col6" class="col_heading level0 col6" >DL85 f1_mean</th>
#       <th id="T_33fd3_level0_col7" class="col_heading level0 col7" >DL85 f1_std</th>
#       <th id="T_33fd3_level0_col8" class="col_heading level0 col8" >sklearn f1_mean</th>
#       <th id="T_33fd3_level0_col9" class="col_heading level0 col9" >sklearn f1_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_
td>
#     </tr>
#     <tr>
#       <th id="T_33fd3_level0_row4" class="row_heading level0 row4" >BIN:Rice</th>
#       <td id="T_33fd3_row4_col0" class="data row4 col0" >0.926127</td>
#       <td id="T_33fd3_row4_col1" class="data row4 col1" >0.006839</td>
#       <td id="T_33fd3_row4_col2" class="data row4 col2" >0.919265</td>
#       <td id="T_33fd3_row4_col3" class="data row4 col3" >0.012133</td>
#       <td id="T_33fd3_row4_col4" class="data row4 col4" >0.926751</td>
#       <td id="T_33fd3_row4_col5" class="data row4 col5" >0.004741</td>
#       <td id="T_33fd3_row4_col6" class="data row4 col6" >0.924574</td>
#       <td id="T_33fd3_row4_col7" class="data row4 col7" >0.008003</td>
#       <td id="T_33fd3_row4_col8" class="data row4 col8" >0.927018</td>
#       <td id="T_33fd3_row4_col9" class="data row4 col9" >0.005883</td>
#     </tr>
#     <tr>
#       <th id="T_33fd3_level0_row5" class="row_heading level0 row5" >BIN:Echocardiogram</th>
#       <td id="T_33fd3_row5_col0" class="data row5 col0" >0.658150</td>
#       <td id="T_33fd3_row5_col1" class="data row5 col1" >0.113106</td>
#       <td id="T_33fd3_row5_col2" class="data row5 col2" >0.622376</td>
#       <td id="T_33fd3_row5_col3" class="data row5 col3" >0.113815</td>
#       <td id="T_33fd3_row5_col4" class="data row5 col4" >0.628410</td>
#       <td id="T_33fd3_row5_col5" class="data row5 col5" >0.105045</td>
#       <td id="T_33fd3_row5_col6" class="data row5 col6" >0.608611</td>
#       <td id="T_33fd3_row5_col7" class="data row5 col7" >0.112447</td>
#       <td id="T_33fd3_row5_col8" class="data row5 col8" >0.554570</td>
#       <td id="T_33fd3_row5_col9" class="data row5 col9" >0.111094</td>
#     </tr>
#     <tr>
#       <th id="T_33fd3_level0_row6" class="row_heading level0 row6" >BIN:Wisconsin Diagnostic Breast Cancer</th>
#       <td id="T_33fd3_row6_col0" class="data row6 col0" >0.903999</td>
#       <td id="T_33fd3_row6_col1" class="data row6 col1" >0.021564</td>
#       <td id="T_33fd3_row6_col2" class="data row6 col2" >0.912713</td>
#       <td id="T_33fd3_row6_col3" class="data row6 col3" >0.031851</td>
#       <td id="T_33fd3_row6_col4" class="data row6 col4" >0.892163</td>
#       <td id="T_33fd3_row6_col5" class="data row6 col5" >0.028223</td>
#       <td id="T_33fd3_row6_col6" class="data row6 col6" >0.895669</td>
#       <td id="T_33fd3_row6_col7" class="data row6 col7" >0.020549</td>
#       <td id="T_33fd3_row6_col8" class="data row6 col8" >0.886121</td>
#       <td id="T_33fd3_row6_col9" class="data row6 col9" >0.025305</td>
#     </tr>
#     <tr>
#       <th id="T_33fd3_level0_row7" class="row_heading level0 row7" >BIN:Loan House</th>
#       <td id="T_33fd3_row7_col0" class="data row7 col0" >0.713970</td>
#       <td id="T_33fd3_row7_col1" class="data r
# <style type="text/css">
# #T_e1613_row0_col0, #T_e1613_row1_col0, #T_e1613_row2_col0, #T_e1613_row3_col6, #T_e1613_row4_col0, #T_e1613_row5_col0, #T_e1613_row6_col2, #T_e1613_row7_col0, #T_e1613_row8_col8, #T_e1613_row9_col0, #T_e1613_row10_col8, #T_e1613_row11_col8, #T_e1613_row12_col0, #T_e1613_row13_col0, #T_e1613_row14_col0, #T_e1613_row15_col0, #T_e1613_row16_col0, #T_e1613_row17_col8, #T_e1613_row18_col0, #T_e1613_row19_col8, #T_e1613_row20_col4, #T_e1613_row21_col0, #T_e1613_row24_col0 {
#   background-color: #9CC95C;
# }
# #T_e1613_row0_col4, #T_e1613_row1_col4, #T_e1613_row2_col6, #T_e1613_row3_col8, #T_e1613_row4_col8, #T_e1613_row5_col8, #T_e1613_row6_col8, #T_e1613_row7_col4, #T_e1613_row8_col6, #T_e1613_row9_col6, #T_e1613_row10_col4, #T_e1613_row11_col4, #T_e1613_row12_col6, #T_e1613_row13_col4, #T_e1613_row14_col4, #T_e1613_row15_col4, #T_e1613_row16_col4, #T_e1613_row17_col4, #T_e1613_row18_col4, #T_e1613_row19_col4, #T_e1613_row20_col8, #T_e1613_row21_col4, #T_e1613_row24_col4 {
#   background-color: #FF6961;
# }
# </style>
# <table id="T_e1613">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1613_level0_col0" class="col_heading level0 col0" >GDT roc_auc_mean</th>
#       <th id="T_e1613_level0_col1" class="col_heading level0 col1" >GDT roc_auc_std</th>
#       <th id="T_e1613_level0_col2" class="col_heading level0 col2" >DNDT roc_auc_mean</th>
#       <th id="T_e1613_level0_col3" class="col_heading level0 col3" >DNDT roc_auc_std</th>
#       <th id="T_e1613_level0_col4" class="col_heading level0 col4" >GeneticTree roc_auc_mean</th>
#       <th id="T_e1613_level0_col5" class="col_heading level0 col5" >GeneticTree roc_auc_std</th>
#       <th id="T_e1613_level0_col6" class="col_heading level0 col6" >DL85 roc_auc_mean</th>
#       <th id="T_e1613_level0_col7" class="col_heading level0 col7" >DL85 roc_auc_std</th>
#       <th id="T_e1613_level0_col8" class="col_heading level0 col8" >sklearn roc_auc_mean</th>
#       <th id="T_e1613_level0_col9" class="col_heading level0 col9" >sklearn roc_auc_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1613_level0_row0" class="row_heading level0 row0" >BIN:Blood Transfusion</th>
#       <td id="T_e1613_row0_col0" class="data row0 col0" >0.682779</td>
#       <td id="T_e1613_row0_col1" class="data row0 col1" >0.049563</td>
#       <td id="T_e1613_row0_col2" class="data row0 col2" >0.636721</td>
#       <td id="T_e1613_row0_col3" class="data row0 col3" >0.078843</td>
#       <td id="T_e1613_row0_col4" class="data row0 col4" >0.623149</td>
#       <td id="T_e1613_row0_col5" class="data row0 col5" >0.087188</td>
#       <td id="T_e1613_row0_col6" class="data row0 col6" >0.662774</td>
#       <td id="T_e1613_row0_col7" class="data row0 col7" >0.040886</td>
#       <td id="T_e1613_row0_col8" class="data row0 col8" >0.630092</td>
#       <td id="T_e1613_row0_col9" class="data row0 col9" >0.058469</td>
#     </tr>
#     <tr>
#       <th id="T_e1613_level0_row1" class="row_heading level0 row1" >BIN:Banknote Authentication</th>
#       <td id="T_e1613_row1_col0" class="data row1 col0" >0.994843</td>
#       <td id="T_e1613_row1_col1" class="data row1 col1" >0.005346</td>
#       <td id="T_e1613_row1_col2" class="data row1 col2" >0.951354</td>
#       <td id="T_e1613_row1_col3" class="data row1 col3" >0.012788</td>
#       <td id="T_e1613_row1_col4" class="data row1 col4" >0.939739</td>
#       <td id="T_e1613_row1_col5" class="data row1 col5" >0.020201</td>
#       <td id="T_e1613_row1_col6" class="data row1 col6" >0.982521</td>
#       <td id="T_e1613_row1_col7" class="data row1 col7" >0.006564</td>
#       <td id="T_e1613_row1_col8" class="data row1 col8" >0.981367</td>
#       <td id="T_e1613_row1_col9" class="data row1 col9" >0.006884</td>
#     </tr>
#     <tr>
#       <th id="T_e1613_level0_row2" class="row_heading level0 row2" >BIN:Titanic</th>
#       <td id="T
td>
#     </tr>
#     <tr>
#       <th id="T_e1613_level0_row6" class="row_heading level0 row6" >BIN:Wisconsin Diagnostic Breast Cancer</th>
#       <td id="T_e1613_row6_col0" class="data row6 col0" >0.953923</td>
#       <td id="T_e1613_row6_col1" class="data row6 col1" >0.019832</td>
#       <td id="T_e1613_row6_col2" class="data row6 col2" >0.959764</td>
#       <td id="T_e1613_row6_col3" class="data row6 col3" >0.018439</td>
#       <td id="T_e1613_row6_col4" class="data row6 col4" >0.892654</td>
#       <td id="T_e1613_row6_col5" class="data row6 col5" >0.032846</td>
#       <td id="T_e1613_row6_col6" class="data row6 col6" >0.912119</td>
#       <td id="T_e1613_row6_col7" class="data row6 col7" >0.036577</td>
#       <td id="T_e1613_row6_col8" class="data row6 col8" >0.891039</td>
#       <td id="T_e1613_row6_col9" class="data row6 col9" >0.029539</td>
#     </tr>
#     <tr>
#       <th id="T_e1613_level0_row7" class="row_heading level0 row7" >BIN:Loan House</th>
#       <td id="T_e1613_row7_col0" class="data row7 col0" >0.719878</
# <style type="text/css">
# #T_7325b_row0_col2, #T_7325b_row1_col2, #T_7325b_row2_col2, #T_7325b_row3_col2, #T_7325b_row4_col2, #T_7325b_row5_col2, #T_7325b_row6_col8, #T_7325b_row7_col4, #T_7325b_row8_col6, #T_7325b_row9_col4, #T_7325b_row9_col8, #T_7325b_row10_col4, #T_7325b_row11_col0, #T_7325b_row12_col6, #T_7325b_row13_col8, #T_7325b_row14_col0, #T_7325b_row15_col6, #T_7325b_row16_col4, #T_7325b_row17_col6, #T_7325b_row18_col4, #T_7325b_row19_col6, #T_7325b_row20_col6, #T_7325b_row21_col6, #T_7325b_row24_col2 {
#   background-color: #FF6961;
# }
# #T_7325b_row0_col4, #T_7325b_row1_col0, #T_7325b_row2_col0, #T_7325b_row3_col4, #T_7325b_row4_col8, #T_7325b_row5_col0, #T_7325b_row6_col2, #T_7325b_row7_col0, #T_7325b_row8_col8, #T_7325b_row9_col0, #T_7325b_row10_col8, #T_7325b_row11_col8, #T_7325b_row12_col0, #T_7325b_row13_col0, #T_7325b_row14_col4, #T_7325b_row15_col0, #T_7325b_row16_col0, #T_7325b_row17_col0, #T_7325b_row18_col0, #T_7325b_row19_col8, #T_7325b_row20_col0, #T_7325b_row21_col8, #T_7325b_row24_col0 {
#   background-color: #9CC95C;
# }
# </style>
# <table id="T_7325b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7325b_level0_col0" class="col_heading level0 col0" >GDT accuracy_mean</th>
#       <th id="T_7325b_level0_col1" class="col_heading level0 col1" >GDT accuracy_std</th>
#       <th id="T_7325b_level0_col2" class="col_heading level0 col2" >DNDT accuracy_mean</th>
#       <th id="T_7325b_level0_col3" class="col_heading level0 col3" >DNDT accuracy_std</th>
#       <th id="T_7325b_level0_col4" class="col_heading level0 col4" >GeneticTree accuracy_mean</th>
#       <th id="T_7325b_level0_col5" class="col_heading level0 col5" >GeneticTree accuracy_std</th>
#       <th id="T_7325b_level0_col6" class="col_heading level0 col6" >DL85 accuracy_mean</th>
#       <th id="T_7325b_level0_col7" class="col_heading level0 col7" >DL85 accuracy_std</th>
#       <th id="T_7325b_level0_col8" class="col_heading level0 col8" >sklearn accuracy_mean</th>
#       <th id="T_7325b_level0_col9" class="col_heading level0 col9" >sklearn accuracy_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7325b_level0_row0" class="row_heading level0 row0" >BIN:Blood Transfusion</th>
#       <td id="T
td>
#     </tr>
#     <tr>
#       <th id="T_7325b_level0_row4" class="row_heading level0 row4" >BIN:Rice</th>
#       <td id="T_7325b_row4_col0" class="data row4 col0" >0.927822</td>
#       <td id="T_7325b_row4_col1" class="data row4 col1" >0.006794</td>
#       <td id="T_7325b_row4_col2" class="data row4 col2" >0.921654</td>
#       <td id="T_7325b_row4_col3" class="data row4 col3" >0.010933</td>
#       <td id="T_7325b_row4_col4" class="data row4 col4" >0.927822</td>
#       <td id="T_7325b_row4_col5" class="data row4 col5" >0.004980</td>
#       <td id="T_7325b_row4_col6" class="data row4 col6" >0.926509</td>
#       <td id="T_7325b_row4_col7" class="data row4 col7" >0.008068</td>
#       <td id="T_7325b_row4_col8" class="data row4 col8" >0.928609</td>
#       <td id="T_7325b_row4_col9" class="data row4 col9" >0.006133</td>
#     </tr>
#     <tr>
#       <th id="T_7325b_level0_row5" class="row_heading level0 row5" >BIN:Echocardiogram</th>
#       <td id="T_7325b_row5_col0" class="data row5 col0" >0.765385</td>
#       <td id="T_7325b_row5_col1" class="data row5 col1" >0.097983</td>
#       <td id="T_7325b_row5_col2" class="data row5 col2" >0.696154</td>
#       <td id="T_7325b_row5_col3" class="data row5 col3" >0.071852</td>
#       <td id="T_7325b_row5_col4" class="data row5 col4" >0.742308</td>
#       <td id="T_7325b_row5_col5" class="data row5 col5" >0.080769</td>
#       <td id="T_7325b_row5_col6" class="data row5 col6" >0.703846</td>
#       <td id="T_7325b_row5_col7" class="data row5 col7" >0.111538</td>
#       <td id="T_7325b_row5_col8" class="data row5 col8" >0.696154</td>
#       <td id="T_7325b_row5_col9" class="data row5 col9" >0.094915</td>
#     </tr>
#     <tr>
#       <th id="T_7325b_level0_row6" class="row_heading level0 row6" >BIN:Wisconsin Diagnostic Breast Cancer</th>
#       <td id="T_7325b_row6_col0" class="data row6 col0" >0.910619</td>
#       <td id="T_7325b_row6_col1" class="data row6 col1" >0.019966</td>
#       <td id="T_7325b_row6_col2" class="data row6 col2" >0.919469</td>
#       <td id="T_7325b_row6_col3" class="data row6 col3" >0.029997</td>
#       <td id="T_7325b_row6_col4" class="data row6 col4" >0.901770</td>
#       <td id="T_7325b_row6_col5" class="data row6 col5" >0.025480</td>
#       <td id="T_7325b_row6_col6" class="data row6 col6" >0.903540</td>
#       <td id="T_7325b_row6_col7" class="data row6 col7" >0.021109</td>
#       <td id="T_7325b_row6_col8" class="data row6 col8" >0.893805</td>
#       <td id="T_7325b_row6_col9" class="data row6 col9" >0.024715</td>
#     </tr>
#     <tr>
#       <th id="T_7325b_level0_row7" class="row_heading level0 row7" >BIN:Loan House</th>
#       <td id="T_7325b_row7_col0" clas
# <style type="text/css">
# #T_5f860_row0_col4, #T_5f860_row1_col4, #T_5f860_row2_col4, #T_5f860_row3_col8, #T_5f860_row4_col4, #T_5f860_row4_col8, #T_5f860_row5_col4, #T_5f860_row6_col8, #T_5f860_row7_col4, #T_5f860_row8_col4, #T_5f860_row9_col4, #T_5f860_row10_col4, #T_5f860_row11_col4, #T_5f860_row12_col0, #T_5f860_row12_col4, #T_5f860_row13_col4, #T_5f860_row14_col4, #T_5f860_row15_col4, #T_5f860_row16_col4, #T_5f860_row17_col4, #T_5f860_row18_col4, #T_5f860_row19_col4, #T_5f860_row20_col4, #T_5f860_row21_col4, #T_5f860_row24_col4 {
#   background-color: #FF6961;
# }
# #T_5f860_row0_col8, #T_5f860_row1_col0, #T_5f860_row2_col2, #T_5f860_row3_col2, #T_5f860_row4_col2, #T_5f860_row5_col2, #T_5f860_row6_col2, #T_5f860_row7_col2, #T_5f860_row8_col2, #T_5f860_row9_col6, #T_5f860_row10_col8, #T_5f860_row11_col8, #T_5f860_row12_col6, #T_5f860_row13_col0, #T_5f860_row14_col6, #T_5f860_row15_col6, #T_5f860_row16_col6, #T_5f860_row17_col8, #T_5f860_row18_col6, #T_5f860_row19_col0, #T_5f860_row20_col8, #T_5f860_row21_col8, #T_5f860_row24_col2 {
#   background-color: #9CC95C;
# }
# </style>
# <table id="T_5f860">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f860_level0_col0" class="col_heading level0 col0" >GDT total_nodes_mean</th>
#       <th id="T_5f860_level0_col1" class="col_heading level0 col1" >GDT total_nodes_std</th>
#       <th id="T_5f860_level0_col2" class="col_heading level0 col2" >DNDT total_nodes_mean</th>
#       <th id="T_5f860_level0_col3" class="col_heading level0 col3" >DNDT total_nodes_std</th>
#       <th id="T_5f860_level0_col4" class="col_heading level0 col4" >GeneticTree total_nodes_mean</th>
#       <th id="T_5f860_level0_col5" class="col_heading level0 col5" >GeneticTree total_nodes_std</th>
#       <th id="T_5f860_level0_col6" class="col_heading level0 col6" >DL85 total_nodes_mean</th>
#       <th id="T_5f860_level0_col7" class="col_heading level0 col7" >DL85 total_nodes_std</th>
#       <th id="T_5f860_level0_col8" class="col_heading level0 col8" >sklearn total_nodes_mean</th>
#       <th id="T_5f860_level0_col9" class="col_heading level0 col9" >sklearn total_nodes_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f860_level0_row0" class="row_heading level0 row0" >BIN:Blood Transfusion</th>
#       <td id="T_5f860_row0_col0" class="data row0 col0" >29.200000</td>
#       <td id="T_5f860_row0_col1" class="data row0 col1" >8.219489</td>
#       <td id="T_5f860_row0_col2" class="data row0 col2" >24.000000</td>
#       <td id="T_5f860_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_5f860_row0_col4" class="data row0 col4" >5.200000</td>
#       <td id="T_5f860_row0_col5" class="data row0 col5" >3.026549</td>
#       <td id="T_5f860_row0_col6" class="data row0 col6" >35.500000</td>
#       <td id="T_5f860_row0_col7" class="data row0 col7" >2.418677</td>
#       <td id="T_5f860_row0_col8" class="data row0 col8" >165.600000</td>
#       <td id="T_5f860_row0_col9" class="data row0 col9" >21.836666</td>
#     </tr>
#     <tr>
#       <th id="T_5f860_level0_row1" class="row_heading level0 row1" >BIN:Banknote Authentication</th>
#       <td id="T_5f860_row1_col0" class="data row1 col0" >60.000000</td>
#       <td id="T_5f860_row1_col1" class="data row1 col1" >11.216060</td>
#       <td id="T_5f860_row1_col2" class="data row1 col2" >24.000000</td>
#       <td id="T_5f860_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_5f860_row1_col4" class="data row1 col4" >12.800000</td>
#       <td id="T_5f860_row1_col5" class="data row1 col5" >5.325411</td>
#       <td id="T_5f860_row1_col6" class="data row1 col6" >39.700000</td>
#       <td id="T_5f860_row1_col7" class="data row1 col7" >0.900000</td>
#       <td id="T_5f860_row1_col8" class="data row1 col8" >44.800000</td>
#       <td id="T_5f860_row1_col9" class="data row1 col9" >4.686150</td>
#     </tr>
#     <tr>
#       <th id="T_5f860_level0_row2" class="row_heading level0 row2" >BIN:Titanic</th>
#       <td id="T_5f860_row2_col0" class="data row2 col0" >39.600000</td>
#       <td id="T_5f860_row2_col1" class="data row2 col1" >10.160709</td>
#       <td id="T_5f860_row2_col2" class="data row2 col2" >142.000000</td>
#       <td id="T_5f860_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_5f860_row2_col4" class="data row2 col4" >10.400000</td>
#       <td id="T_5f860_row2_col5" class="data row2 col5" >3.104835</td>
#       <td id="T_5f860_row2_col6" class="data row2 col6" >41.800000</td>
#       <td id="T_5f860_row2_col7" class="data row2 col7" >1.469694</td>
#       <td id="T_5f860_row2_col8" class="data row2 col8" >21.600000</td>
#       <td id="T_5f860_row2_col9" class="data row2 col9" >0.916515</td>
#     </tr>
#     <tr>
#       <th id="T_5f860_level0_row3" class="row_heading level0 row3" >BIN:Raisins</th>
#       <td id="T_5f860_row3_col0" class="data row3 col0" >114.800000</td>
#       <td id="T_5f860_row3_col1" class="data row3 col1" >33.686199</td>
#       <td id="T_5f860_row3_col2" class="data row3 col2" >142.000000</td>
#       <td id="T_5f860_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_5f860_row3_col4" class="data row3 col4" >3.600000</td>
#       <td id="T_5f860_row3_col5" class="data row3 col5" >1.800000</td>
#       <td id="T_5f860_row3_col6" class="data row3 col6" >43.600000</td>
#       <td id="T_5f860_row3_col7" class="data row3 col7" >2.244994</td>
#       <td id="T_5f860_row3_col8" class="data row3 col8" >3.000000</td>
#       <td id="T_5f860_row3_col9" class="data row3 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5f860_level0_row4" class="row_heading level0 row4" >BIN:Rice</th>
#       <td id="T_5f860_row4_col0" class="data row4 col0" >41.000000</td>
#       <td id="T_5f860_row4_col1" class="data row4 col1" >10.039920</td>
#       <td id="T_5f860_row4_col2" class="data row4 col2" >142.000000</td>
#       <td id="T_5f860_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_5f860_row4_col4" class="data row4 col4" >3.000000</td>
#       <td id="T_5f860_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_5f860_row4_col6" class="data row4 col6" >44.800000</td>
#       <td id="T_5f860_row4_col7" class="data row4 col7" >1.469694</td>
#       <td id="T_5f860_row4_col8" class="data row4 col8" >3.000000</td>
#       <td id="T_5f860_row4_col9" class="data row4 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5f860_level0_row5" class="row_heading level0 row5" >BIN:Echocardiogram</th>
#       <td id="T_5f860_row5_col0" class="data row5 col0" >43.200000</td>
#       <td id="T_5f860_row5_col1" class="data row5 col1" >12.820296</td>
#       <td id="T_5f860_row5_col2" class="data row5 col2" >272.000000</td>
#       <td id="T_5f860_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_5f860_row5_col4" class="data row5 col4" >9.000000</td>
#       <td id="T_5f860_row5_col5" class="data row5 col5" >3.098387</td>
#       <td id="T_5f860_row5_col6" class="data row5 col6" >44.500000</td>
#       <td id="T_5f860_row5_col7" class="data row5 col7" >2.012461</td>
#       <td id="T_5f860_row5_col8" class="data row5 col8" >36.200000</td>
#       <td id="T_5f860_row5_col9" class="data row5 col9" >5.810336</td>
#     </tr>
#     <tr>
#       <th id="T_5f860_level0_row6" class="row_heading level0 row6" >BIN:Wisconsin Diagnostic Breast Cancer</th>
#       <td id="T_5f860_row6_col0" class="data row6 col0" >61.800000</td>
#       <td id="T_5f860_row6_col1" class="data row6 col1" >13.362634</td>
#       <td id="T_5f860_row6_col2" class="data row6 col2" >1044.000000</td>
#       <td id="T_5f860_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_5f860_row6_col4" class="data row6 col4" >4.000000</td>
#       <td id="T_5f860_row6_col5" class="data row6 col5" >1.612452</td>
#       <td id="T_5f860_row6_col6" class="data row6 col6" >43.600000</td>
#       <td id="T_5f860_row6_col7" class="data row6 col7" >1.200000</td>
#       <td id="T_5f860_row6_col8" class="data row6 col8" >3.000000</td>
#       <td id="T_5f860_row6_col9" class="data row6 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5f860_level0_row
# <style type="text/css">
# #T_88b53_row0_col4, #T_88b53_row1_col4, #T_88b53_row2_col4, #T_88b53_row3_col8, #T_88b53_row4_col4, #T_88b53_row4_col8, #T_88b53_row5_col4, #T_88b53_row6_col8, #T_88b53_row7_col4, #T_88b53_row8_col4, #T_88b53_row9_col4, #T_88b53_row10_col4, #T_88b53_row11_col4, #T_88b53_row12_col0, #T_88b53_row12_col4, #T_88b53_row13_col4, #T_88b53_row14_col4, #T_88b53_row15_col4, #T_88b53_row16_col4, #T_88b53_row17_col4, #T_88b53_row18_col4, #T_88b53_row19_col4, #T_88b53_row20_col4, #T_88b53_row21_col4, #T_88b53_row24_col4 {
#   background-color: #FF6961;
# }
# #T_88b53_row0_col8, #T_88b53_row1_col0, #T_88b53_row2_col0, #T_88b53_row3_col0, #T_88b53_row4_col0, #T_88b53_row5_col0, #T_88b53_row6_col0, #T_88b53_row7_col2, #T_88b53_row8_col2, #T_88b53_row9_col0, #T_88b53_row10_col8, #T_88b53_row11_col8, #T_88b53_row12_col6, #T_88b53_row13_col0, #T_88b53_row14_col6, #T_88b53_row15_col8, #T_88b53_row16_col0, #T_88b53_row17_col8, #T_88b53_row18_col6, #T_88b53_row19_col0, #T_88b53_row20_col8, #T_88b53_row21_col8, #T_88b53_row24_col0 {
#   background-color: #9CC95C;
# }
# </style>
# <table id="T_88b53">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88b53_level0_col0" class="col_heading level0 col0" >GDT internal_node_num_mean</th>
#       <th id="T_88b53_level0_col1" class="col_heading level0 col1" >GDT internal_node_num_std</th>
#       <th id="T_88b53_level0_col2" class="col_heading level0 col2" >DNDT internal_node_num_mean</th>
#       <th id="T_88b53_level0_col3" class="col_heading level0 col3" >DNDT internal_node_num_std</th>
#       <th id="T_88b53_level0_col4" class="col_heading level0 col4" >GeneticTree internal_node_num_mean</th>
#       <th id="T_88b53_level0_col5" class="col_heading level0 col5" >GeneticTree internal_node_num_std</th>
#       <th id="T_88b53_level0_col6" class="col_heading level0 col6" >DL85 internal_node_num_mean</th>
#       <th id="T_88b53_level0_col7" class="col_heading level0 col7" >DL85 internal_node_num_std</th>
#       <th id="T_88b53_level0_col8" class="col_heading level0 col8" >sklearn internal_node_num_mean</th>
#       <th id="T_88b53_level0_col9" class="col_heading level0 col9" >sklearn internal_node_num_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88b53_level0_row0" class="row_heading level0 row0" >BIN:Blood Transfusion</th>
#       <td id="T_88b53_row0_col0" class="data row0 col0" >14.100000</td>
#       <td id="T_88b53_row0_col1" class="data row0 col1" >4.109745</td>
#       <td id="T_88b53_row0_col2" class="data row0 col2" >8.000000</td>
#       <td id="T_88b53_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_88b53_row0_col4" class="data row0 col4" >2.100000</td>
#       <td id="T_88b53_row0_col5" class="data row0 col5" >1.513275</td>
#       <td id="T_88b53_row0_col6" class="data row0 col6" >11.500000</td>
#       <td id="T_88b53_row0_col7" class="data row0 col7" >0.806226</td>
#       <td id="T_88b53_row0_col8" class="data row0 col8" >82.300000</td>
#       <td id="T_88b53_row0_col9" class="data row0 col9" >10.918333</td>
#     </tr>
#     <tr>
#       <th id="T_88b53_level0_row1" class="row_heading level0 row1" >BIN:Banknote Authentication</th>
#       <td id="T_88b53_row1_col0" class="data row1 col0" >29.500000</td>
#       <td id="T_88b53_row1_col1" class="data row1 col1" >5.608030</td>
#       <td id="T_88b53_row1_col2" class="data row1 col2" >8.000000</td>
#       <td id="T_88b53_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_88b53_row1_col4" class="data row1 col4" >5.900000</td>
#       <td id="T_88b53_row1_col5" class="data row1 col5" >2.662705</td>
#       <td id="T_88b53_row1_col6" class="data row1 col6" >12.900000</td>
#       <td id="T_88b53_row1_col7" class="data row1 col7" >0.300000</td>
#       <td id="T_88b53_row1_col8" class="data row1 col8" >21.900000</td>
#       <td id="T_88b53_row1_col9" class="data row1 col9" >2.343075</td>
#     </tr>
#     <tr>
#       <th id="T_88b53_level0_row2" class="row_heading level0 row2" >BIN:Titanic</th>
#       <td id="T
row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_88b53_row6_col4" class="data row6 col4" >1.500000</td>
#       <td id="T_88b53_row6_col5" class="data row6 col5" >0.806226</td>
#       <td id="T_88b53_row6_col6" class="data row6 col6" >14.200000</td>
#       <td id="T_88b53_row6_col7" class="data row6 col7" >0.400000</td>
#       <td id="T_88b53_row6_col8" class="data row6 col8" >1.000000</td>
#       <td id="T_88b53_row6_col9" class="data row6 col9" >0.000000</td>
#     </tr
# <style type="text/css">
# #T_39458_row0_col4, #T_39458_row1_col4, #T_39458_row2_col4, #T_39458_row3_col8, #T_39458_row4_col4, #T_39458_row4_col8, #T_39458_row5_col4, #T_39458_row6_col8, #T_39458_row7_col4, #T_39458_row8_col4, #T_39458_row9_col4, #T_39458_row10_col4, #T_39458_row11_col4, #T_39458_row12_col0, #T_39458_row12_col4, #T_39458_row13_col4, #T_39458_row14_col4, #T_39458_row15_col4, #T_39458_row16_col4, #T_39458_row17_col4, #T_39458_row18_col4, #T_39458_row19_col4, #T_39458_row20_col4, #T_39458_row21_col4, #T_39458_row24_col4 {
#   background-color: #FF6961;
# }
# #T_39458_row0_col8, #T_39458_row1_col0, #T_39458_row2_col2, #T_39458_row3_col2, #T_39458_row4_col2, #T_39458_row5_col2, #T_39458_row6_col2, #T_39458_row7_col2, #T_39458_row8_col2, #T_39458_row9_col6, #T_39458_row10_col8, #T_39458_row11_col8, #T_39458_row12_col6, #T_39458_row13_col0, #T_39458_row14_col6, #T_39458_row15_col6, #T_39458_row16_col6, #T_39458_row17_col8, #T_39458_row18_col6, #T_39458_row19_col0, #T_39458_row20_col8, #T_39458_row21_col8, #T_39458_row24_col2 {
#   background-color: #9CC95C;
# }
# </style>
# <table id="T_39458">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39458_level0_col0" class="col_heading level0 col0" >GDT leaf_node_num_mean</th>
#       <th id="T_39458_level0_col1" class="col_heading level0 col1" >GDT leaf_node_num_std</th>
#       <th id="T_39458_level0_col2" class="col_heading level0 col2" >DNDT leaf_node_num_mean</th>
#       <th id="T_39458_level0_col3" class="col_heading level0 col3" >DNDT leaf_node_num_std</th>
#       <th id="T_39458_level0_col4" class="col_heading level0 col4" >GeneticTree leaf_node_num_mean</th>
#       <th id="T_39458_level0_col5" class="col_heading level0 col5" >GeneticTree leaf_node_num_std</th>
#       <th id="T_39458_level0_col6" class="col_heading level0 col6" >DL85 leaf_node_num_mean</th>
#       <th id="T_39458_level0_col7" class="col_heading level0 col7" >DL85 leaf_node_num_std</th>
#       <th id="T_39458_level0_col8" class="col_heading level0 col8" >sklearn leaf_node_num_mean</th>
#       <th id="T_39458_level0_col9" class="col_heading level0 col9" >sklearn leaf_node_num_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39458_level0_row0" class="row_heading level0 row0" >BIN:Blood Transfusion</th>
#       <td id="T_39458_row0_col0" class="data row0 col0" >15.100000</td>
#       <td id="T_39458_row0_col1" class="data row0 col1" >4.109745</td>
#       <td id="T_39458_row0_col2" class="data row0 col2" >16.000000</td>
#       <td id="T_39458_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_39458_row0_col4" class="data row0 col4" >3.100000</td>
#       <td id="T_39458_row0_col5" class="data row0 col5" >1.513275</td>
#       <td id="T_39458_row0_col6" class="data row0 col6" >24.000000</td>
#       <td id="T_39458_row0_col7" class="data row0 col7" >1.612452</td>
#       <td id="T_39458_row0_col8" class="data row0 col8" >83.300000</td>
#       <td id="T_39458_row0_col9" class="data row0 col9" >10.918333</td>
#     </tr>
#     <tr>
#       <th id="T_39458_level0_row1" class="row_heading level0 row1" >BIN:Banknote Authentication</th>
#       <td id="T
level0_row6" class="row_heading level0 row6" >BIN:Wisconsin Diagnostic Breast Cancer</th>
#       <td id="T_39458_row6_col0" class="data row6 col0" >31.400000</td>
#       <td id="T_39458_row6_col1" class="data row6 col1" >6.681317</td>
#       <td id="T_39458_row6_col2" class="data row6 col2" >1024.000000</td>
#       <td id="T_39458_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_39458_row6_col4" class="data row6 col4" >2.500000</td>
#       <td id="T_39458_row6_col5" class="data row6 col5" >0.806226</td>
#       <td id="T_39458_row6_col6" class="data row6 col6" >29.400000</td>
#       <td id="T_39458_row6_col7" class="data row6 col7" >0.800000</td>
#       <td id="T_39458_row6_col8" class="data row6 col8" >2.000000</td>
#       <td id="T_39458_row6_col9" class="data row6 col9" >0.000000</td>
#     </tr>
#     <tr>
# ...
# #T_8505d_row0_col4, #T_8505d_row1_col4, #T_8505d_row2_col4, #T_8505d_row3_col8, #T_8505d_row4_col4, #T_8505d_row4_col8, #T_8505d_row5_col4, #T_8505d_row6_col8, #T_8505d_row7_col4, #T_8505d_row8_col4, #T_8505d_row9_col4, #T_8505d_row10_col4, #T_8505d_row11_col4, #T_8505d_row12_col0, #T_8505d_row12_col4, #T_8505d_row13_col4, #T_8505d_row14_col4, #T_8505d_row15_col4, #T_8505d_row16_col4, #T_8505d_row17_col4, #T_8505d_row18_col4, #T_8505d_row19_col4, #T_8505d_row20_col4, #T_8505d_row21_col4, #T_8505d_row24_col4 {
#   background-color: #FF6961;
# }
# #T_8505d_row0_col8, #T_8505d_row1_col0, #T_8505d_row2_col0, #T_8505d_row3_col0, #T_8505d_row4_col0, #T_8505d_row5_col0, #T_8505d_row6_col0, #T_8505d_row7_col2, #T_8505d_row8_col2, #T_8505d_row9_col0, #T_8505d_row10_col8, #T_8505d_row11_col8, #T_8505d_row12_col6, #T_8505d_row13_col0, #T_8505d_row14_col6, #T_8505d_row15_col8, #T_8505d_row16_col0, #T_8505d_row17_col8, #T_8505d_row18_col6, #T_8505d_row19_col0, #T_8505d_row20_col8, #T_8505d_row21_col8, #T_8505d_row24_col0 {
#   background-color: #9CC95C;
# }
# </style>
# <table id="T_8505d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8505d_level0_col0" class="col_heading level0 col0" >GDT internal_node_num_mean</th>
#       <th id="T_8505d_level0_col1" class="col_heading level0 col1" >GDT internal_node_num_std</th>
#       <th id="T_8505d_level0_col2" class="col_heading level0 col2" >DNDT internal_node_num_mean</th>
#       <th id="T_8505d_level0_col3" class="col_heading level0 col3" >DNDT internal_node_num_std</th>
#       <th id="T_8505d_level0_col4" class="col_heading level0 col4" >GeneticTree internal_node_num_mean</th>
#       <th id="T_8505d_level0_col5" class="col_heading level0 col5" >GeneticTree internal_node_num_std</th>
#       <th id="T_8505d_level0_col6" class="col_heading level0 col6" >DL85 internal_node_num_mean</th>
#       <th id="T_8505d_level0_col7" class="col_heading level0 col7" >DL85 internal_node_num_std</th>
#       <th id="T_8505d_level0_col8" class="col_heading level0 col8" >sklearn internal_node_num_mean</th>
#       <th id="T_8505d_level0_col9" class="col_heading level0 col9" >sklearn internal_node_num_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8505d_level0_row0" class="row_heading level0 row0" >BIN:Blood Transfusion</th>
#       <td id="T
row4_col9" class="data row4 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8505d_level0_row5" class="row_heading level0 row5" >BIN:Echocardiogram</th>
#       <td id="T_8505d_row5_col0" class="data row5 col0" >21.100000</td>
#       <td id="T_8505d_row5_col1" class="data row5 col1" >6.410148</td>
#       <td id="T_8505d_row5_col2" class="data row5 col2" >16.000000</td>
#       <td id="T_8505d_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_8505d_row5_col4" class="data row5 col4" >4.000000</td>
#       <td id="T_8505d_row5_col5" class="data row5 col5" >1.549193</td>
#       <td id="T_8505d_row5_col6" class="data row5 col6" >14.500000</td>
#       <td id="T_8505d_row5_col7" class="data row5 col7" >0.670820</td>
#       <td id="T_8505d_row5_col8" class="data row5 col8" >17.600000</td>
#       <td id="T_8505d_row5_col9" class="data row5 col9" >2.905168</td>
#     </tr>
#     <tr>
#       <th id="T_8505d_level0_row6" class="row_heading level0 row6" >BIN:Wisconsin Diagnostic Breast Cancer</th>
#       <td id="T_8505d_row6_col0" class="data row6 col0" >30.400000</td>
#       <td id="T_8505d_row6_col1" class="data row6 col1" >6.681317</td>
#       <td id="T_8505d_row6_col2" class="data row6 col2" >20.000000</td>
#       <td id="T_8505d_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_8505d_row6_col4" class="data row6 col4" >1.500000</td>
#       <td id="T_8505d_row6_col5" class="data row6 col5" >0.806226</td>
#       <td id="T_8505d_row6_col6" class="data row6 col6" >14.200000</td>
#       <td id="T_8505d_row6_col7" class="data row6 col7" >0.400000</td>
#       <td id="T_8505d_row6_col8" class="data row6 col8" >1.000000</td>
#       <td id="T_8505d_row6_col9" class="data row6 col9" >0.000000</td>
#     </tr
# <style type="text/css">
# #T_c88bb_row0_col4, #T_c88bb_row1_col4, #T_c88bb_row2_col4, #T_c88bb_row3_col8, #T_c88bb_row4_col4, #T_c88bb_row4_col8, #T_c88bb_row5_col4, #T_c88bb_row6_col8, #T_c88bb_row7_col4, #T_c88bb_row8_col4, #T_c88bb_row9_col4, #T_c88bb_row10_col4, #T_c88bb_row11_col4, #T_c88bb_row12_col0, #T_c88bb_row12_col4, #T_c88bb_row13_col4, #T_c88bb_row14_col4, #T_c88bb_row15_col4, #T_c88bb_row16_col4, #T_c88bb_row17_col4, #T_c88bb_row18_col4, #T_c88bb_row19_col4, #T_c88bb_row20_col4, #T_c88bb_row21_col4, #T_c88bb_row24_col4 {
#   background-color: #FF6961;
# }
# #T_c88bb_row0_col8, #T_c88bb_row1_col0, #T_c88bb_row2_col2, #T_c88bb_row3_col2, #T_c88bb_row4_col2, #T_c88bb_row5_col2, #T_c88bb_row6_col2, #T_c88bb_row7_col2, #T_c88bb_row8_col2, #T_c88bb_row9_col6, #T_c88bb_row10_col8, #T_c88bb_row11_col8, #T_c88bb_row12_col6, #T_c88bb_row13_col0, #T_c88bb_row14_col6, #T_c88bb_row15_col6, #T_c88bb_row16_col6, #T_c88bb_row17_col8, #T_c88bb_row18_col6, #T_c88bb_row19_col0, #T_c88bb_row20_col8, #T_c88bb_row21_col8, #T_c88bb_row24_col2 {
#   background-color: #9CC95C;
# }
# </style>
# <table id="T_c88bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c88bb_level0_col0" class="col_heading level0 col0" >GDT leaf_node_num_mean</th>
#       <th id="T_c88bb_level0_col1" class="col_heading level0 col1" >GDT leaf_node_num_std</th>
#       <th id="T_c88bb_level0_col2" class="col_heading level0 col2" >DNDT leaf_node_num_mean</th>
#       <th id="T_c88bb_level0_col3" class="col_heading level0 col3" >DNDT leaf_node_num_std</th>
#       <th id="T_c88bb_level0_col4" class="col_heading level0 col4" >GeneticTree leaf_node_num_mean</th>
#       <th id="T_c88bb_level0_col5" class="col_heading level0 col5" >GeneticTree leaf_node_num_std</th>
#       <th id="T_c88bb_level0_col6" class="col_heading level0 col6" >DL85 leaf_node_num_mean</th>
#       <th id="T_c88bb_level0_col7" class="col_heading level0 col7" >DL85 leaf_node_num_std</th>
#       <th id="T_c88bb_level0_col8" class="col_heading level0 col8" >sklearn leaf_node_num_mean</th>
#       <th id="T_c88bb_level0_col9" class="col_heading level0 col9" >sklearn leaf_node_num_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c88bb_level0_row0" class="row_heading level0 row0" >BIN:Blood Transfusion</th>
#       <td id="T_c88bb_row0_col0" class="data row0 col0" >15.100000</td>
#       <td id="T_c88bb_row0_col1" class="data row0 col1" >4.109745</td>
#       <td id="T_c88bb_row0_col2" class="data row0 col2" >16.000000</td>
#       <td id="T_c88bb_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_c88bb_row0_col4" class="data row0 col4" >3.100000</td>
#       <td id="T_c88bb_row0_col5" class="data row0 col5" >1.513275</td>
#       <td id="T_c88bb_row0_col6" class="data row0 col6" >24.000000</td>
#       <td id="T_c88bb_row0_col7" class="data row0 col7" >1.612452</td>
#       <td id="T_c88bb_row0_col8" class="data row0 col8" >83.300000</td>
#       <td id="T_c88bb_row0_col9" class="data row0 col9" >10.918333</td>
#     </tr>
#     <tr>
#       <th id="T_c88bb_level0_row1" class="row_heading level0 row1" >BIN:Banknote Authentication</th>
#       <td id="T_c88bb_row1_col0" class="data row1 col0" >30.500000</td>
#       <td id="T_c88bb_row1_col1" class="data row1 col1" >5.608030</td>
#       <td id="T_c88bb_row1_col2" class="data row1 col2" >16.000000</td>
#       <td id="T_c88bb_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_c88bb_row1_col4" class="data row1 col4" >6.900000</td>
#       <td id="T_c88bb_row1_col5" class="data row1 col5" >2.662705</td>
#       <td id="T_c88bb_row1_col6" class="data row1 col6" >26.800000</td>
#       <td id="T_c88bb_row1_col7" class="data row1 col7" >0.600000</td>
#       <td id="T_c88bb_row1_col8" class="data row1 col8" >22.900000</td>
#       <td id="T_c88bb_row1_col9" class="data row1 col9" >2.343075</td>
#     </tr>
#     <tr>
#       <th id="T_c88bb_level0_row2" class="row_heading level0 row2" >BIN:Titanic</th>
#       <td id="T_c88bb_row2_col0" class="data row2 col0" >20.300000</td>
#       <td id="T_c88bb_row2_col1" class="data row2 col1" >5.080354</td>
#       <td id="T_c88bb_row2_col2" class="data row2 col2" >128.000000</td>
#       <td id="T_c88bb_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_c88bb_row2_col4" class="data row2 col4" >5.700000</td>
#       <td id="T_c88bb_row2_col5" class="data row2 col5" >1.552417</td>
#       <td id="T_c88bb_row2_col6" class="data row2 col6" >28.200000</td>
#       <td id="T_c88bb_row2_col7" class="data row2 col7" >0.979796</td>
#       <td id="T_c88bb_row2_col8" class="data row2 col8" >11.300000</td>
#       <td id="T_c88bb_row2_col9" class="data row2 col9" >0.458258</td>
#     </tr>
#     <tr>
#       <th id="T_c88bb_level0_row3" class="row_heading level0 row3" >BIN:Raisins</th>
#       <td id="T_c88bb_row3_col0" class="data row3 col0" >57.900000</td>
#       <td id="T_c88bb_row3_col1" class="data row3 col1" >16.843099</td>
#       <td id="T_c88bb_row3_col2" class="data row3 col2" >128.000000</td>
#       <td id="T_c88bb_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_c88bb_row3_col4" class="data row3 col4" >2.300000</td>
#       <td id="T_c88bb_row3_col5" class="data row3 col5" >0.900000</td>
#       <td id="T_c88bb_row3_col6" class="data row3 col6" >29.400000</td>
#       <td id="T_c88bb_row3_col7" class="data row3 col7" >1.496663</td>
#       <td id="T_c88bb_row3_col8" class="data row3 col8" >2.000000</td>
#       <td id="T_c88bb_row3_col9" class="data row3 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c88bb_level0_row4" class="row_heading level0 row4" >BIN:Rice</th>
#       <td id="T_c88bb_row4_col0" class="data row4 col0" >21.000000</td>
#       <td id="T_c88bb_row4_col1" class="data row4 col1" >5.019960</td>
#       <td id="T_c88bb_row4_col2" class="data row4 col2" >128.000000</td>
#       <td id="T_c88bb_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_c88bb_row4_col4" class="data row4 col4" >2.000000</td>
#       <td id="T_c88bb_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_c88bb_row4_col6" class="data row4 col6" >30.200000</td>
#       <td id="T_c88bb_row4_col7" class="data row4 col7" >0.979796</td>
#       <td id="T_c88bb_row4_col8" class="data row4 col8" >2.000000</td>
#       <td id="T_c88bb_row4_col9" class="data row4 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c88bb_level0_row5" class="row_heading level0 row5" >BIN:Echocardiogram</th>
#       <td id="T_c88bb_row5_col0" class="data row5 col0" >22.100000</td>
#       <td id="T_c88bb_row5_col1" class="data row5 col1" >6.410148</td>
#       <td id="T_c88bb_row5_col2" class="data row5 col2" >256.000000</td>
#       <td id="T_c88bb_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_c88bb_row5_col4" class="data row5 col4" >5.000000</td>
#       <td id="T_c88bb_row5_col5" class="data row5 col5" >1.549193</td>
#       <td id="T_c88bb_row5_col6" class="data row5 col6" >30.000000</td>
#       <td id="T_c88bb_row5_col7" class="data row5 col7" >1.341641</td>
#       <td id="T_c88bb_row5_col8" class="data row5 col8" >18.600000</td>
#       <td id="T_c88bb_row5_col9" class="data row5 col9" >2.905168</td>
#     </tr>
#     <tr>
#       <th id="T_c88bb_level0_row6" class="row_heading level0 row6" >BIN:Wisconsin Diagnostic Breast Cancer</th>
#       <td id="T_c88bb_row6_col0" class="data row6 col0" >31.400000</td>
#       <td id="T_c88bb_row6_col1" class="data row6 col1" >6.681317</td>
#       <td id="T_c88bb_row6_col2" class="data row6 col2" >1024.000000</td>
#       <td id="T_c88bb_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_c88bb_row6_col4" class="data row6 col4" >2.500000</td>
#       <td id="T_c88bb_row6_col5" class="data row6 col5" >0.806226</td>
#       <td id="T_c88bb_row6_col6" class="data row6 col6" >29.400000</td>
#       <td id="T_c88bb_row6_col7" class="data row6 col7" >0.800000</td>
#       <td id="T_c88bb_row6_col8" class="data row6 col8" >2.000000</td>
#       <td id="T_c88bb_row6_col9" class="data row6 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c88bb

# %%
from numba import cuda 
if config['computation']['use_gpu']:
    device = cuda.get_current_device()
    device.reset()
