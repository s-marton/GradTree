# %% [markdown]
# # Imports

# %%
 config = {
    'gdt': {
        'depth': 10,
        
        'learning_rate_index': 0.05,
        'learning_rate_values': 0.01,
        'learning_rate_leaf': 0.05,
        
        'split_index_activation': 'entmax',
                
        'optimizer': 'SWA', #adam with stochastic weight averaging
        
        'initializer': 'GlorotUniform', 
        
        'dropout': 0,
        
        'prunePostHoc': True,
        'prune_threshold': 1,
        
        'batch_size': 128,#512,
        'epochs': 10_000,
        
        'loss': 'binary_crossentropy', #binary_focal_crossentropy, binary_crossentropy
        
        'focalLossGamma': 3,
        
        'polyLoss': False,
        'polyLossEpsilon': 2,
        
        'restarts': 3,
        'restart_type': 'loss', #'loss', 'metric'
        
        'early_stopping_epochs': 200,
        'early_stopping_type': 'loss', #'loss', 'metric'
        'early_stopping_epsilon': 0.0,
    },
    
    'preprocessing': {
        'balance_threshold': 0.25,#.25, #if minclass fraction less than threshold/num_classes-1 | #0=no rebalance, 1=rebalance all
        'normalization_technique': 'quantile', #'min-max'
        'quantile_noise': 1e-3,
    },

    'computation': {
        'random_seed': 42,
        'trials': 10,
        
        'use_best_hpo_result': True,
        'hpo_path': '_HPO',
        
        'force_depth': False,
        'force_dropout': False,
        'force_restart': True,   
        
        'use_gpu': True,
        'gpu_numbers': '0',#'1',
        'n_jobs': 10,
        'verbosity': 0,
        
        'hpo': None,
        'search_iterations': 300,
        'cv_num': 3,     
        
        'metrics_class': ['f1', 'roc_auc', 'accuracy', 'total_nodes','internal_node_num', 'leaf_node_num'],      
        'eval_metric_class': ['f1', 'roc_auc', 'accuracy', 'total_nodes', 'internal_node_num', 'leaf_node_num'], #f1 accuracy
    },
    
    'benchmarks': {
        'DNDT': True,
        'GeneticTree': True,
        'DL85': True,
        
        'sklearn': True,
        
        'NeuralNetwork': False,
    }
}

# %%
import numpy as np
np.set_printoptions(suppress=True)

import sklearn
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split, ParameterGrid, ParameterSampler, GridSearchCV, RandomizedSearchCV, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier, plot_tree, DecisionTreeRegressor
from sklearn.metrics import accuracy_score, f1_score, make_scorer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, LabelEncoder, OrdinalEncoder
from pydl85 import DL85Classifier

from livelossplot import PlotLosses

import os
from tqdm.notebook import tqdm
from matplotlib import pyplot as plt

from IPython.display import Image
from IPython.display import display, clear_output

import pandas as pd

if config['computation']['use_gpu']:
    os.environ['CUDA_VISIBLE_DEVICES'] = str(config['computation']['gpu_numbers'])
    os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
    os.environ['XLA_FLAGS'] = "--xla_gpu_cuda_data_dir=/usr/local/cuda-11.6"
    os.environ['TF_XLA_FLAGS'] = "--tf_xla_enable_xla_devices --tf_xla_auto_jit=2"    
else:
    os.environ['CUDA_VISIBLE_DEVICES'] = ''
    os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'false' 
#os.environ['TF_XLA_FLAGS'] = "--tf_xla_auto_jit=2 --tf_xla_cpu_global_jit" 


import warnings
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
os.environ["PYTHONWARNINGS"] = "ignore"
import logging

import tensorflow as tf
import tensorflow_addons as tfa

tf.get_logger().setLevel('ERROR')
tf.autograph.set_verbosity(3)

np.seterr(all="ignore")

from keras import backend as K

import seaborn as sns
sns.set_style("darkgrid")

import time
import random

from utilities.utilities_GDT import *
from utilities.GDT import *
from utilities.DNDT import *

from joblib import Parallel, delayed

from itertools import product
from collections.abc import Iterable

from copy import deepcopy
from pathlib import Path
import pickle
import dill

tf.random.set_seed(config['computation']['random_seed'])
np.random.seed(config['computation']['random_seed'])
random.seed(config['computation']['random_seed'])
tf.keras.utils.set_random_seed(config['computation']['random_seed'])

from datetime import datetime
timestr = datetime.utcnow().strftime('%Y-%m-%d--%H-%M-%S%f')
print(timestr)
os.makedirs(os.path.dirname("./evaluation_results" + config['computation']['hpo_path'] + "/latex_tables/" + timestr +"/"), exist_ok=True)

filepath = './evaluation_results' + config['computation']['hpo_path'] + '/depth' + str(config['gdt']['depth']) + '/' + timestr + '/'
Path(filepath).mkdir(parents=True, exist_ok=True)    

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

from joblib.externals.loky import set_loky_pickler
set_loky_pickler("dill")
# Out:
# 2023-04-28--13-21-20052148

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print("Num XLA-GPUs Available: ", len(tf.config.experimental.list_physical_devices('XLA_GPU')))
# Out:
# Num GPUs Available:  1
# Num XLA-GPUs Available:  1

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Real-World Eval

# %% [markdown]
# ### Classification

# %%
identifier_list_classification_multi = [
                        'MULT:Iris',# 150 4 3
                        'MULT:Balance Scale',# 625 4 3
                        'MULT:Car',# 1728 6 4
                        'MULT:Glass',# 214 9 6 
                        'MULT:Contraceptive',# 1473 9 3 
                        'MULT:Solar Flare',# 1389 10 8
                        'MULT:Wine',# 178 12 3
                        'MULT:Zoo',#101 16 7   ###TD
                        'MULT:Lymphography',# 148 18 4 ###TD
                        'MULT:Segment',# 2310 19 7
                        'MULT:Dermatology',# 366 34 6
                        'MULT:Landsat',# 6435 36 6
                        'MULT:Annealing',# 798 38 5
                        'MULT:Splice',# 3190 60 3
                  ]

# %%
benchmark_dict = get_benchmark_dict(config=config, eval_identifier='classification')

metrics = ['f1', 'roc_auc', 'accuracy']

parallel_eval_real_world = Parallel(n_jobs=min(config['computation']['n_jobs'], config['computation']['trials']), verbose=3, backend='loky') #loky #sequential multiprocessing
evaluation_results_real_world_classification_multi = parallel_eval_real_world(delayed(evaluate_real_world_parallel_nested)(identifier_list=identifier_list_classification_multi[::-1], 
                                                                                                       random_seed_data=config['computation']['random_seed']+i,
                                                                                                       random_seed_model=config['computation']['random_seed'],
                                                                                                       config = config,
                                                                                                       benchmark_dict = benchmark_dict,
                                                                                                       metrics = config['computation']['metrics_class'],
                                                                                                       verbosity = -1) for i in range(config['computation']['trials']))
# Out:
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 60.0min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 61.7min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 62.2min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 65.2min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 65.5min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 65.9min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 66.2min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 67.9min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 68.6min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 71.1min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 71.5min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 71.7min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 72.5min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 72.9min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 73.3min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 74.7min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 77.0min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 77.5min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 78.2min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 79.2min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 125.4min finished
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 126.4min finished
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 129.5min finished
# [Parallel(n_jobs=10)]: Done   3 out of  10 | elapsed: 129.7min remaining: 302.6min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 136.5min finished
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 138.8min finished
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 140.2min finished
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 140.4min finished
# [Parallel(n_jobs=10)]: Done   7 out of  10 | elapsed: 140.6min remaining: 60.3min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 141.5min finished
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 143.0min finished
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 143.9min finished
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed: 144.1min finished

# %%
plot_table_save_results(benchmark_dict=benchmark_dict,
                        evaluation_results_real_world=evaluation_results_real_world_classification_multi,
                        identifier_list=identifier_list_classification_multi,                            
                        identifier_string='multi_test',
                        filepath=filepath,
                        config=config)      

plot_table_save_results(benchmark_dict=benchmark_dict,
                        evaluation_results_real_world=evaluation_results_real_world_classification_multi,
                        identifier_list=identifier_list_classification_multi,                            
                        identifier_string='multi_valid',
                        filepath=filepath,
                        config=config)  

plot_table_save_results(benchmark_dict=benchmark_dict,
                        evaluation_results_real_world=evaluation_results_real_world_classification_multi,
                        identifier_list=identifier_list_classification_multi,                            
                        identifier_string='multi_train',
                        filepath=filepath,
                        config=config)
# Out:
# <style type="text/css">
# #T_c065b_row0_col0, #T_c065b_row1_col0, #T_c065b_row2_col8, #T_c065b_row3_col8, #T_c065b_row4_col0, #T_c065b_row5_col2, #T_c065b_row6_col0, #T_c065b_row7_col8, #T_c065b_row8_col0, #T_c065b_row9_col8, #T_c065b_row10_col8, #T_c065b_row11_col8, #T_c065b_row12_col8, #T_c065b_row13_col8, #T_c065b_row16_col8 {
#   background-color: #9CC95C;
# }
# #T_c065b_row0_col2, #T_c065b_row1_col2, #T_c065b_row2_col6, #T_c065b_row3_col2, #T_c065b_row4_col4, #T_c065b_row5_col6, #T_c065b_row6_col6, #T_c065b_row7_col4, #T_c065b_row8_col4, #T_c065b_row9_col4, #T_c065b_row10_col4, #T_c065b_row11_col4, #T_c065b_row12_col4, #T_c065b_row13_col4, #T_c065b_row16_col4 {
#   background-color: #FF6961;
# }
# </style>
# <table id="T_c065b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c065b_level0_col0" class="col_heading level0 col0" >GDT f1_mean</th>
#       <th id="T_c065b_level0_col1" class="col_heading level0 col1" >GDT f1_std</th>
#       <th id="T_c065b_level0_col2" class="col_heading level0 col2" >DNDT f1_mean</th>
#       <th id="T_c065b_level0_col3" class="col_heading level0 col3" >DNDT f1_std</th>
#       <th id="T_c065b_level0_col4" class="col_heading level0 col4" >GeneticTree f1_mean</th>
#       <th id="T_c065b_level0_col5" class="col_heading level0 col5" >GeneticTree f1_std</th>
#       <th id="T_c065b_level0_col6" class="col_heading level0 col6" >DL85 f1_mean</th>
#       <th id="T_c065b_level0_col7" class="col_heading level0 col7" >DL85 f1_std</th>
#       <th id="T_c065b_level0_col8" class="col_heading level0 col8" >sklearn f1_mean</th>
#       <th id="T_c065b_level0_col9" class="col_heading level0 col9" >sklearn f1_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c065b_level0_row0" class="row_heading level0 row0" >MULT:Iris</th>
#       <td id="T_c065b_row0_col0" class="data row0 col0" >0.938420</td>
#       <td id="T_c065b_row0_col1" class="data row0 col1" >0.056567</td>
#       <td id="T_c065b_row0_col2" class="data row0 col2" >0.870034</td>
#       <td id="T_c065b_row0_col3" class="data row0 col3" >0.062699</td>
#       <td id="T_c065b_row0_col4" class="data row0 col4" >0.912245</td>
#       <td id="T_c065b_row0_col5" class="data row0 col5" >0.054510</td>
#       <td id="T_c065b_row0_col6" class="data row0 col6" >0.909454</td>
#       <td id="T_c065b_row0_col7" class="data row0 col7" >0.046425</td>
#       <td id="T_c065b_row0_col8" class="data row0 col8" >0.937378</td>
#       <td id="T_c065b_row0_col9" class="data row0 col9" >0.045666</td>
#     </tr>
#     <tr>
#       <th id="T_c065b_level0_row1" class="row_heading level0 row1" >MULT:Balance Scale</th>
#       <td id="T_c065b_row1_col0" class="data row1 col0" >0.593085</td>
#       <td id="T_c065b_row1_col1" class="data row1 col1" >0.044750</td>
#       <td id="T_c065b_row1_col2" class="data row1 col2" >0.474803</td>
#       <td id="T_c065b_row1_col3" class="data row1 col3" >0.103812</td>
#       <td id="T_c065b_row1_col4" class="data row1 col4" >0.529137</td>
#       <td id="T_c065b_row1_col5" class="data row1 col5" >0.043153</td>
#       <td id="T_c065b_row1_col6" class="data row1 col6" >0.525034</td>
#       <td id="T_c065b_row1_col7" class="data row1 col7" >0.038878</td>
#       <td id="T_c065b_row1_col8" class="data row1 col8" >0.574044</td>
#       <td id="T_c065b_row1_col9" class="data row1 col9" >0.029688</td>
#     </tr>
#     <tr>
#       <th id="T_c065b_level0_row2" class="row_heading level0 row2" >MULT:Car</th>
#       <td id="T
td>
#     </tr>
#     <tr>
#       <th id="T_c065b_level0_row6" class="row_heading level0 row6" >MULT:Wine</th>
#       <td id="T_c065b_row6_col0" class="data row6 col0" >0.933181</td>
#       <td id="T_c065b_row6_col1" class="data row6 col1" >0.031151</td>
#       <td id="T_c065b_row6_col2" class="data row6 col2" >0.857982</td>
#       <td id="T_c065b_row6_col3" class="data row6 col3" >0.040801</td>
#       <td id="T_c065b_row6_col4" class="data row6 col4" >0.887708</td>
#       <td id="T_c065b_row6_col5" class="data row6 col5" >0.038722</td>
#       <td id="T_c065b_row6_col6" class="data row6 col6" >0.851525</td>
#       <td id="T_c065b_row6_col7" class="data row6 col7" >0.022012</td>
#       <td id="T_c065b_row6_col8" class="data row6 col8" >0.906639</td>
#       <td id="T_c065b_row6_col9" class="data row6 col9" >0.042002</td>
#     </tr>
#     <tr>
#       <th id="T_c065b_level0_row7" class="row_heading level0 row7" >MULT:Zoo</th>
#       <td id="T_c065b_row7_col0" class="data row7 col0" >0.874371</td>
#       <td id="T_c065b_row7_col1" class="data row7 col1" >0.110932</td>
#       <td id="T_c065b_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_c065b_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_c065b_row7_col4" class="data row7 col4" >0.782124</td>
#       <td id="T_c065b_row7_col5" class="data row7 col5" >0.111440</td>
#       <td id="T_c065b_row7_col6" class="data row7 col6" >0.910952</td>
#       <td id="T_c0
# <style type="text/css">
# #T_cd828_row0_col0, #T_cd828_row1_col0, #T_cd828_row2_col2, #T_cd828_row3_col0, #T_cd828_row4_col0, #T_cd828_row5_col8, #T_cd828_row6_col0, #T_cd828_row7_col4, #T_cd828_row8_col0, #T_cd828_row9_col0, #T_cd828_row10_col0, #T_cd828_row11_col0, #T_cd828_row12_col8, #T_cd828_row13_col0, #T_cd828_row16_col0 {
#   background-color: #9CC95C;
# }
# #T_cd828_row0_col6, #T_cd828_row1_col6, #T_cd828_row2_col6, #T_cd828_row3_col2, #T_cd828_row4_col4, #T_cd828_row5_col2, #T_cd828_row6_col6, #T_cd828_row7_col0, #T_cd828_row8_col6, #T_cd828_row9_col4, #T_cd828_row10_col4, #T_cd828_row11_col4, #T_cd828_row12_col4, #T_cd828_row13_col4, #T_cd828_row16_col6 {
#   background-color: #FF6961;
# }
# </style>
# <table id="T_cd828">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd828_level0_col0" class="col_heading level0 col0" >GDT roc_auc_mean</th>
#       <th id="T_cd828_level0_col1" class="col_heading level0 col1" >GDT roc_auc_std</th>
#       <th id="T_cd828_level0_col2" class="col_heading level0 col2" >DNDT roc_auc_mean</th>
#       <th id="T_cd828_level0_col3" class="col_heading level0 col3" >DNDT roc_auc_std</th>
#       <th id="T_cd828_level0_col4" class="col_heading level0 col4" >GeneticTree roc_auc_mean</th>
#       <th id="T_cd828_level0_col5" class="col_heading level0 col5" >GeneticTree roc_auc_std</th>
#       <th id="T_cd828_level0_col6" class="col_heading level0 col6" >DL85 roc_auc_mean</th>
#       <th id="T_cd828_level0_col7" class="col_heading level0 col7" >DL85 roc_auc_std</th>
#       <th id="T_cd828_level0_col8" class="col_heading level0 col8" >sklearn roc_auc_mean</th>
#       <th id="T_cd828_level0_col9" class="col_heading level0 col9" >sklearn roc_auc_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd828_level0_row0" class="row_heading level0 row0" >MULT:Iris</th>
#       <td id="T_cd828_row0_col0" class="data row0 col0" >0.970424</td>
#       <td id="T_cd828_row0_col1" class="data row0 col1" >0.031429</td>
#       <td id="T_cd828_row0_col2" class="data row0 col2" >0.943459</td>
#       <td id="T_cd828_row0_col3" class="data row0 col3" >0.025249</td>
#       <td id="T_cd828_row0_col4" class="data row0 col4" >0.948861</td>
#       <td id="T_cd828_row0_col5" class="data row0 col5" >0.040174</td>
#       <td id="T_cd828_row0_col6" class="data row0 col6" >0.940408</td>
#       <td id="T_cd828_row0_col7" class="data row0 col7" >0.025793</td>
#       <td id="T_cd828_row0_col8" class="data row0 col8" >0.964617</td>
#       <td id="T_cd828_row0_col9" class="data row0 col9" >0.021163</td>
#     </tr>
#     <tr>
#       <th id="T_cd828_level0_row1" class="row_heading level0 row1" >MULT:Balance Scale</th>
#       <td id="T

#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83c00_level0_col0" class="col_heading level0 col0" >GDT accuracy_mean</th>
#       <th id="T_83c00_level0_col1" class="col_heading level0 col1" >GDT accuracy_std</th>
#       <th id="T_83c00_level0_col2" class="col_heading level0 col2" >DNDT accuracy_mean</th>
#       <th id="T_83c00_level0_col3" class="col_heading level0 col3" >DNDT accuracy_std</th>
#       <th id="T_83c00_level0_col4" class="col_heading level0 col4" >GeneticTree accuracy_mean</th>
#       <th id="T_83c00_level0_col5" class="col_heading level0 col5" >GeneticTree accuracy_std</th>
#       <th id="T_83c00_level0_col6" class="col_heading level0 col6" >DL85 accuracy_mean</th>
#       <th id="T_83c00_level0_col7" class="col_heading level0 col7" >DL85 accuracy_std</th>
#       <th id="T_83c00_level0_col8" class="col_heading level0 col8" >sklearn accuracy_mean</th>
#       <th id="T_83c00_level0_col9" class="col_heading level0 col9" >sklearn accuracy_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83c00_level0_row0" class="row_heading level0 row0" >MULT:Iris</th>
#       <td id="T_83c00_row0_col0" class="data row0 col0" >0.940000</td>
#       <td id="T_83c00_row0_col1" class="data row0 col1" >0.057349</td>
#       <td id="T_83c00_row0_col2" class="data row0 col2" >0.876667</td>
#       <td id="T_83c00_row0_col3" class="data row0 col3" >0.059722</td>
#       <td id="T_83c00_row0_col4" class="data row0 col4" >0.916667</td>
#       <td id="T_83c00_row0_col5" class="data row0 col5" >0.050000</td>
#       <td id="T_83c00_row0_col6" class="data row0 col6" >0.913333</td>
#       <td id="T_83c00_row0_col7" class="data row0 col7" >0.042687</td>
#       <td id="T_83c00_row0_col8" class="data row0 col8" >0.940000</td>
#       <td id="T_83c00_row0_col9" class="data row0 col9" >0.044222</td>
#     </tr>
#     <tr>
#       <th id="T_83c00_level0_row1" class="row_heading level0 row1" >MULT:Balance Scale</th>
#       <td id="T_83c00_row1_col0" class="data row1 col0" >0.722400</td>
#       <td id="T_83c00_row1_col1" class="data row1 col1" >0.037017</td>
#       <td id="T_83c00_row1_col2" class="data row1 col2" >0.511200</td>
#       <td id="T_83c00_row1_col3" class="data row1 col3" >0.111510</td>
#       <td id="T_83c00_row1_col4" class="data row1 col4" >0.668800</td>
#       <td id="T_83c00_row1_col5" class="data row1 col5" >0.056817</td>
#       <td id="T_83c00_row1_col6" class="data row1 col6" >0.658400</td>
#       <td id="T_83c00_row1_col7" class="data row1 col7" >0.035063</td>
#       <td id="T_83c00_row1_col8" class="data row1 col8" >0.732000</td>
#       <td id="T_83c00_row1_col9" class="data row1 col9" >0.023799</td>
#     </tr>
#     <tr>
#       <th id="T_83c00_level0_row2" class="row_heading level0 row2" >MULT:Car</th>
#       <td id="T_83c00_row2_col0" class="data row2 col0" >0.667826</td>
#       <td id="T_83c00_row2_col1" class="data row2 col1" >0.050208</td>
#       <td id="T_83c00_row2_col2" class="data row2 col2" >0.747246</td>
#       <td id="T_83c00_row2_col3" class="data row2 col3" >0.046806</td>
#       <td id="T_83c00_row2_col4" class="data row2 col4" >0.628986</td>
#       <td id="T_83c00_row2_col5" class="data row2 col5" >0.068531</td>
#       <td id="T_83c00_row2_col6" class="data row2 col6" >0.591884</td>
#       <td id="T_83c00_row2_col7" class="data row2 col7" >0.067528</td>
#       <td id="T_83c00_row2_col8" class="data row2 col8" >0.793043</td>
#       <td id="T_83c00_row2_col9" class="data row2 col9" >0.045760</td>
#     </tr>
#     <tr>
#       <th id="T_83c00_level0_row3" class="row_heading level0 row3" >MULT:Glass</th>
#       <td id="T
row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_83c00_row7_col4" class="data row7 col4" >0.890000</td>
#       <td id="T_83c00_row7_col5" class="data row7 col5" >0.073485</td>
#       <td
# <style type="text/css">
# #T_184ce_row0_col4, #T_184ce_row1_col2, #T_184ce_row2_col4, #T_184ce_row3_col4, #T_184ce_row4_col4, #T_184ce_row5_col8, #T_184ce_row6_col4, #T_184ce_row7_col8, #T_184ce_row8_col4, #T_184ce_row9_col4, #T_184ce_row10_col4, #T_184ce_row11_col4, #T_184ce_row12_col4, #T_184ce_row13_col4, #T_184ce_row16_col4 {
#   background-color: #FF6961;
# }
# #T_184ce_row0_col6, #T_184ce_row1_col8, #T_184ce_row2_col2, #T_184ce_row3_col2, #T_184ce_row4_col2, #T_184ce_row5_col2, #T_184ce_row6_col2, #T_184ce_row7_col6, #T_184ce_row8_col6, #T_184ce_row9_col0, #T_184ce_row10_col6, #T_184ce_row11_col8, #T_184ce_row12_col6, #T_184ce_row13_col0, #T_184ce_row16_col2 {
#   background-color: #9CC95C;
# }
# </style>
# <table id="T_184ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_184ce_level0_col0" class="col_heading level0 col0" >GDT total_nodes_mean</th>
#       <th id="T_184ce_level0_col1" class="col_heading level0 col1" >GDT total_nodes_std</th>
#       <th id="T_184ce_level0_col2" class="col_heading level0 col2" >DNDT total_nodes_mean</th>
#       <th id="T_184ce_level0_col3" class="col_heading level0 col3" >DNDT total_nodes_std</th>
#       <th id="T_184ce_level0_col4" class="col_heading level0 col4" >GeneticTree total_nodes_mean</th>
#       <th id="T_184ce_level0_col5" class="col_heading level0 col5" >GeneticTree total_nodes_std</th>
#       <th id="T_184ce_level0_col6" class="col_heading level0 col6" >DL85 total_nodes_mean</th>
#       <th id="T_184ce_level0_col7" class="col_heading level0 col7" >DL85 total_nodes_std</th>
#       <th id="T_184ce_level0_col8" class="col_heading level0 col8" >sklearn total_nodes_mean</th>
#       <th id="T_184ce_level0_col9" class="col_heading level0 col9" >sklearn total_nodes_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_184ce_level0_row0" class="row_heading level0 row0" >MULT:Iris</th>
#       <td id="T_184ce_row0_col0" class="data row0 col0" >14.400000</td>
#       <td id="T_184ce_row0_col1" class="data row0 col1" >2.537716</td>
#       <td id="T_184ce_row0_col2" class="data row0 col2" >24.000000</td>
#       <td id="T_184ce_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_184ce_row0_col4" class="data row0 col4" >9.000000</td>
#       <td id="T_184ce_row0_col5" class="data row0 col5" >3.098387</td>
#       <td id="T_184ce_row0_col6" class="data row0 col6" >43.300000</td>
#       <td id="T_184ce_row0_col7" class="data row0 col7" >2.100000</td>
#       <td id="T_184ce_row0_col8" class="data row0 col8" >9.400000</td>
#       <td id="T_184ce_row0_col9" class="data row0 col9" >1.496663</td>
#     </tr>
#     <tr>
#       <th id="T_184ce_level0_row1" class="row_heading level0 row1" >MULT:Balance Scale</th>
#       <td id="T_184ce_row1_col0" class="data row1 col0" >118.600000</td>
#       <td id="T_184ce_row1_col1" class="data row1 col1" >27.096863</td>
#       <td id="T_184ce_row1_col2" class="data row1 col2" >24.000000</td>
#       <td id="T_184ce_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_184ce_row1_col4" class="data row1 col4" >25.400000</td>
#       <td id="T_184ce_row1_col5" class="data row1 col5" >11.306635</td>
#       <td id="T_184ce_row1_col6" class="data row1 col6" >46.000000</td>
#       <td id="T_184ce_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_184ce_row1_col8" class="data row1 col8" >161.200000</td>
#       <td id="T_184ce_row1_col9" class="data row1 col9" >8.919641</td>
#     </tr>
#     <tr>
#       <th id="T_184ce_level0_row2" class="row_heading level0 row2" >MULT:Car</th>
#       <td id="T_184ce_row2_col0" class="data row2 col0" >47.000000</td>
#       <td id="T_184ce_row2_col1" class="data row2 col1" >13.564660</td>
#       <td id="T_184ce_row2_col2" class="data row2 col2" >76.000000</td>
#       <td id="T_184ce_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_184ce_row2_col4" class="data row2 col4" >32.600000</td>
#       <td id="T_184ce_row2_col5" class="data row2 col5" >21.350410</td>
#       <td id="T_184ce_row2_col6" class="data row2 col6" >44.200000</td>
#       <td id="T_184ce_row2_col7" class="data row2 col7" >1.469694</td>
#       <td id="T_184ce_row2_col8" class="data row2 col8" >57.000000</td>
#       <td id="T_184ce_row2_col9" class="data row2 col9" >13.023056</td>
#     </tr>
#     <tr>
#       <th id="T_184ce_level0_row3" class="row_heading level0 row3" >MULT:Glass</th>
#       <td id="T_184ce_row3_col0" class="data row3 col0" >56.800000</td>
#       <td id="T_184ce_row3_col1" class="data row3 col1" >11.007270</td>
#       <td id="T_184ce_row3_col2" class="data row3 col2" >530.000000</td>
#       <td id="T_184ce_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_184ce_row3_col4" class="data row3 col4" >21.800000</td>
#       <td id="T_184ce_row3_col5" class="data row3 col5" >11.530828</td>
#       <td id="T_184ce_row3_col6" class="data row3 col6" >45.400000</td>
#       <td id="T_184ce_row3_col7" class="data row3 col7" >1.200000</td>
#       <td id="T_184ce_row3_col8" class="data row3 col8" >68.000000</td>
#       <td id="T_184ce_row3_col9" class="data row3 col9" >6.340347</td>
#     </tr>
#     <tr>
#       <th id="T_184ce_level0_row4" class="row_heading level0 row4" >MULT:Contraceptive</th>
#       <td id="T_184ce_row4_col0" class="data row4 col0" >40.600000</td>
#       <td id="T_184ce_row4_col1" class="data row4 col1" >11.482160</td>
#       <td id="T_184ce_row4_col2" class="data row4 col2" >530.000000</td>
#       <td id="T_184ce_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_184ce_row4_col4" class="data row4 col4" >12.800000</td>
#       <td id="T_184ce_row4_col5" class="data row4 col5" >3.841875</td>
#       <td id="T_184ce_row4_col6" class="data row4 col6" >44.500000</td>
#       <td id="T_184ce_row4_col7" class="data row4 col7" >2.012461</td>
#       <td id="T_184ce_row4_col8" class="data row4 col8" >48.600000</td>
#       <td id="T_184ce_row4_col9" class="data row4 col9" >7.144228</td>
#     </tr>
#     <tr>
#       <th id="T_184ce_level0_row5" class="row_heading level0 row5" >MULT:Solar Flare</th>
#       <td id="T_184ce_row5_col0" class="data row5 col0" >49.800000</td>
#       <td id="T_184ce_row5_col1" class="data row5 col1" >9.303763</td>
#       <td id="T_184ce_row5_col2" class="data row5 col2" >1044.000000</td>
#       <td id="T_184ce_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_184ce_row5_col4" class="data row5 col4" >38.400000</td>
#       <td id="T_184ce_row5_col5" class="data row5 col5" >21.411212</td>
#       <td id="T_184ce_row5_col6" class="data row5 col6" >39.700000</td>
#       <td id="T_184ce_row5_col7" class="data row5 col7" >4.920366</td>
#       <td id="T_184ce_row5_col8" class="data row5 col8" >32.000000</td>
#       <td id="T_184ce_row5_col9" class="data row5 col9" >3.130495</td>
#     </tr>
#     <tr>
#       <th id="T_184ce_level0_row6" class="row_heading level0 row6" >MULT:Wine</th>
#       <td id="T_184ce_row6_col0" class="data row6 col0" >24.000000</td>
#       <td id="T_184ce_row6_col1" class="data row6 col1" >4.123106</td>
#       <td id="T_184ce_row6_col2" class="data row6 col2" >4120.000000</td>
#       <td id="T_184ce_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_184ce_row6_col4" class="data row6 col4" >11.200000</td>
#       <td id="T_184ce_row6_col5" class="data row6 col5" >4.770744</td>
#       <td id="T_184ce_row6_col6" class="data row6 col6" >41.800000</td>
#       <td id="T_184ce_row6_col7" class="data row6 col7" >2.400000</td>
#       <td id="T_184ce_row6_col8" class="data row6 col8" >13.400000</td>
#       <td id="T_184ce_row6_col9" class="data row6 col9" >2.332381</td>
#     </tr>
#     <tr>
#       <th id="T_184ce_level0_row7" class="row_heading level0 row7" >MULT:Zoo</th>
#       <td id="T_184ce_row7_col0" class="data row7 col0" >25.000000</td>
#       <td id="T_184ce_row7_col1" class="data row7 col1" >3.898718</td>
#       <td id="T_184ce_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_184ce_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_184ce_row7_col4" class="data row7 col4" >32.600000</td>
#       <td id="T_18
# <style type="text/css">
# #T_a93b7_row0_col4, #T_a93b7_row1_col2, #T_a93b7_row2_col2, #T_a93b7_row3_col4, #T_a93b7_row4_col4, #T_a93b7_row5_col6, #T_a93b7_row6_col4, #T_a93b7_row7_col8, #T_a93b7_row8_col4, #T_a93b7_row9_col4, #T_a93b7_row10_col4, #T_a93b7_row11_col4, #T_a93b7_row12_col4, #T_a93b7_row13_col4, #T_a93b7_row16_col4 {
#   background-color: #FF6961;
# }
# #T_a93b7_row0_col6, #T_a93b7_row1_col8, #T_a93b7_row2_col8, #T_a93b7_row3_col8, #T_a93b7_row4_col8, #T_a93b7_row5_col0, #T_a93b7_row6_col2, #T_a93b7_row7_col4, #T_a93b7_row8_col0, #T_a93b7_row9_col0, #T_a93b7_row10_col0, #T_a93b7_row11_col8, #T_a93b7_row12_col6, #T_a93b7_row13_col0, #T_a93b7_row16_col0 {
#   background-color: #9CC95C;
# }
# </style>
# <table id="T_a93b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a93b7_level0_col0" class="col_heading level0 col0" >GDT internal_node_num_mean</th>
#       <th id="T_a93b7_level0_col1" class="col_heading level0 col1" >GDT internal_node_num_std</th>
#       <th id="T_a93b7_level0_col2" class="col_heading level0 col2" >DNDT internal_node_num_mean</th>
#       <th id="T_a93b7_level0_col3" class="col_heading level0 col3" >DNDT internal_node_num_std</th>
#       <th id="T_a93b7_level0_col4" class="col_heading level0 col4" >GeneticTree internal_node_num_mean</th>
#       <th id="T_a93b7_level0_col5" class="col_heading level0 col5" >GeneticTree internal_node_num_std</th>
#       <th id="T_a93b7_level0_col6" class="col_heading level0 col6" >DL85 internal_node_num_mean</th>
#       <th id="T_a93b7_level0_col7" class="col_heading level0 col7" >DL85 internal_node_num_std</th>
#       <th id="T_a93b7_level0_col8" class="col_heading level0 col8" >sklearn internal_node_num_mean</th>
#       <th id="T_a93b7_level0_col9" class="col_heading level0 col9" >sklearn internal_node_num_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a93b7_level0_row0" class="row_heading level0 row0" >MULT:Iris</th>
#       <td id="T_a93b7_row0_col0" class="data row0 col0" >6.700000</td>
#       <td id="T_a93b7_row0_col1" class="data row0 col1" >1.268858</td>
#       <td id="T_a93b7_row0_col2" class="data row0 col2" >8.000000</td>
#       <td id="T_a93b7_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_a93b7_row0_col4" class="data row0 col4" >4.000000</td>
#       <td id="T_a93b7_row0_col5" class="data row0 col5" >1.549193</td>
#       <td id="T_a93b7_row0_col6" class="data row0 col6" >14.100000</td>
#       <td id="T_a93b7_row0_col7" class="data row0 col7" >0.700000</td>
#       <td id="T_a93b7_row0_col8" class="data row0 col8" >4.200000</td>
#       <td id="T_a93b7_row0_col9" class="data row0 col9" >0.748331</td>
#     </tr>
#     <tr>
#       <th id="T_a93b7_level0_row1" class="row_heading level0 row1" >MULT:Balance Scale</th>
#       <td id="T_a93b7_row1_col0" class="data row1 col0" >58.800000</td>
#       <td id="T_a93b7_row1_col1" class="data row1 col1" >13.548432</td>
#       <td id="T_a93b7_row1_col2" class="data row1 col2" >8.000000</td>
#       <td id="T_a93b7_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_a93b7_row1_col4" class="data row1 col4" >12.200000</td>
#       <td id="T_a93b7_row1_col5" class="data row1 col5" >5.653318</td>
#       <td id="T_a93b7_row1_col6" class="data row1 col6" >15.000000</td>
#       <td id="T_a93b7_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T
row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_a93b7_row6_col4" class="data row6 col4" >5.100000</td>
#       <td id="T_a93b7_row6_col5" class="data row6 col5" >2.385372</td>
#       <td id="T_a93b7_row6_col6" class="data row6 col6" >13.600000</td>
#       <td id="T_a93b7_row6_col7" class="data row6 col7" >0.800000</td>
#       <td id="T_a93b7_row6_col8" class="data row6 col8" >6.200000</td>
#       <td id="T_a93b7_row6_col9" class="data row6 col9" >1.166190</td>
#     </tr>
#     <tr>
#       <th id="T_a93b7_level0_row7" class="row_heading level0 row7" >MULT:Zoo</th>
#       <td id="T_a93b7_row7_col0" class="data row7 col0" >12.000000</td>
#       <td id="T_a93b7_row7_col1" class="data row7 col1" >1.949359</td>
#       <td id="T_a93b7_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_a93b7_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_a93b7_row7_col4" class="data row7
# <style type="text/css">
# #T_bf622_row0_col4, #T_bf622_row1_col4, #T_bf622_row2_col4, #T_bf622_row3_col4, #T_bf622_row4_col4, #T_bf622_row5_col8, #T_bf622_row6_col4, #T_bf622_row7_col8, #T_bf622_row8_col4, #T_bf622_row9_col4, #T_bf622_row10_col4, #T_bf622_row11_col4, #T_bf622_row12_col4, #T_bf622_row13_col4, #T_bf622_row16_col4 {
#   background-color: #FF6961;
# }
# #T_bf622_row0_col6, #T_bf622_row1_col8, #T_bf622_row2_col2, #T_bf622_row3_col2, #T_bf622_row4_col2, #T_bf622_row5_col2, #T_bf622_row6_col2, #T_bf622_row7_col6, #T_bf622_row8_col6, #T_bf622_row9_col0, #T_bf622_row10_col6, #T_bf622_row11_col8, #T_bf622_row12_col6, #T_bf622_row13_col0, #T_bf622_row16_col2 {
#   background-color: #9CC95C;
# }
# </style>
# <table id="T_bf622">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf622_level0_col0" class="col_heading level0 col0" >GDT leaf_node_num_mean</th>
#       <th id="T_bf622_level0_col1" class="col_heading level0 col1" >GDT leaf_node_num_std</th>
#       <th id="T_bf622_level0_col2" class="col_heading level0 col2" >DNDT leaf_node_num_mean</th>
#       <th id="T_bf622_level0_col3" class="col_heading level0 col3" >DNDT leaf_node_num_std</th>
#       <th id="T_bf622_level0_col4" class="col_heading level0 col4" >GeneticTree leaf_node_num_mean</th>
#       <th id="T_bf622_level0_col5" class="col_heading level0 col5" >GeneticTree leaf_node_num_std</th>
#       <th id="T_bf622_level0_col6" class="col_heading level0 col6" >DL85 leaf_node_num_mean</th>
#       <th id="T_bf622_level0_col7" class="col_heading level0 col7" >DL85 leaf_node_num_std</th>
#       <th id="T_bf622_level0_col8" class="col_heading level0 col8" >sklearn leaf_node_num_mean</th>
#       <th id="T_bf622_level0_col9" class="col_heading level0 col9" >sklearn leaf_node_num_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf622_level0_row0" class="row_heading level0 row0" >MULT:Iris</th>
#       <td id="T_bf622_row0_col0" class="data row0 col0" >7.700000</td>
#       <td id="T_bf622_row0_col1" class="data row0 col1" >1.268858</td>
#       <td id="T_bf622_row0_col2" class="data row0 col2" >16.000000</td>
#       <td id="T_bf622_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_bf622_row0_col4" class="data row0 col4" >5.000000</td>
#       <td id="T_bf622_row0_col5" class="data row0 col5" >1.549193</td>
#       <td id="T_bf622_row0_col6" class="data row0 col6" >29.200000</td>
#       <td id="T_bf622_row0_col7" class="data row0 col7" >1.400000</td>
#       <td id="T_bf622_row0_col8" class="data row0 col8" >5.200000</td>
#       <td id="T_bf622_row0_col9" class="data row0 col9" >0.748331</td>
#     </tr>
#     <tr>
#       <th id="T_bf622_level0_row1" class="row_heading level0 row1" >MULT:Balance Scale</th>
#       <td id="T_bf622_row1_col0" class="data row1 col0" >59.800000</td>
#       <td id="T_bf622_row1_col1" class="data row1 col1" >13.548432</td>
#       <td id="T_bf622_row1_col2" class="data row1 col2" >16.000000</td>
#       <td id="T_bf622_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T
td>
#     </tr>
#     <tr>
#       <th id="T_bf622_level0_row6" class="row_heading level0 row6" >MULT:Wine</th>
#       <td id="T_bf622_row6_col0" class="data row6 col0" >12.500000</td>
#       <td id="T_bf622_row6_col1" class="data row6 col1" >2.061553</td>
#       <td id="T_bf622_row6_col2" class="data row6 col2" >4096.000000</td>
#       <td id="T_bf622_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_bf622_row6_col4" class="data row6 col4" >6.100000</td>
#       <td id="T_bf622_row6_col5" class="data row6 col5" >2.385372</td>
#       <td id="T_bf622_row6_col6" class="data row6 col6" >28.200000</td>
#       <td id="T_bf622_row6_col7" class="data row6 col7" >1.600000</td>
#       <td id="T_bf622_row6_col8" class="data row6 col8" >7.200000</td>
#       <td id="T_bf622_row6_col9" class="data row6 col9" >1.166190</td>
#     </tr>
#     <tr>
#       <th id="T_bf622_level0_row7" class="row_heading level0 row7" >MULT:Zoo</th>
#       <td id="T_bf622_row7_col0" class="data row7 col0" >13.000000</td>
#       <td id="T_bf622_row7_col1" class="data row7 col1" >1.949359</td>
#       <td id="T_bf622_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_bf622_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_bf622_row7_col4" class="data row7 col4" >16.800000</td>
# ...
# <style type="text/css">
# #T_2ebb1_row0_col4, #T_2ebb1_row1_col2, #T_2ebb1_row2_col2, #T_2ebb1_row3_col4, #T_2ebb1_row4_col4, #T_2ebb1_row5_col6, #T_2ebb1_row6_col4, #T_2ebb1_row7_col8, #T_2ebb1_row8_col4, #T_2ebb1_row9_col4, #T_2ebb1_row10_col4, #T_2ebb1_row11_col4, #T_2ebb1_row12_col4, #T_2ebb1_row13_col4, #T_2ebb1_row16_col4 {
#   background-color: #FF6961;
# }
# #T_2ebb1_row0_col6, #T_2ebb1_row1_col8, #T_2ebb1_row2_col8, #T_2ebb1_row3_col8, #T_2ebb1_row4_col8, #T_2ebb1_row5_col0, #T_2ebb1_row6_col2, #T_2ebb1_row7_col4, #T_2ebb1_row8_col0, #T_2ebb1_row9_col0, #T_2ebb1_row10_col0, #T_2ebb1_row11_col8, #T_2ebb1_row12_col6, #T_2ebb1_row13_col0, #T_2ebb1_row16_col0 {
#   background-color: #9CC95C;
# }
# </style>
# <table id="T_2ebb1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ebb1_level0_col0" class="col_heading level0 col0" >GDT internal_node_num_mean</th>
#       <th id="T_2ebb1_level0_col1" class="col_heading level0 col1" >GDT internal_node_num_std</th>
#       <th id="T_2ebb1_level0_col2" class="col_heading level0 col2" >DNDT internal_node_num_mean</th>
#       <th id="T_2ebb1_level0_col3" class="col_heading level0 col3" >DNDT internal_node_num_std</th>
#       <th id="T_2ebb1_level0_col4" class="col_heading level0 col4" >GeneticTree internal_node_num_mean</th>
#       <th id="T_2ebb1_level0_col5" class="col_heading level0 col5" >GeneticTree internal_node_num_std</th>
#       <th id="T_2ebb1_level0_col6" class="col_heading level0 col6" >DL85 internal_node_num_mean</th>
#       <th id="T_2ebb1_level0_col7" class="col_heading level0 col7" >DL85 internal_node_num_std</th>
#       <th id="T_2ebb1_level0_col8" class="col_heading level0 col8" >sklearn internal_node_num_mean</th>
#       <th id="T_2ebb1_level0_col9" class="col_heading level0 col9" >sklearn internal_node_num_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ebb1_level0_row0" class="row_heading level0 row0" >MULT:Iris</th>
#       <td id="T_2ebb1_row0_col0" class="data row0 col0" >6.700000</td>
#       <td id="T_2ebb1_row0_col1" class="data row0 col1" >1.268858</td>
#       <td id="T_2ebb1_row0_col2" class="data row0 col2" >8.000000</td>
#       <td id="T_2ebb1_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T
row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_2ebb1_row5_col4" class="data row5 col4" >18.700000</td>
#       <td id="T_2ebb1_row5_col5" class="data row5 col5" >10.705606</td>
#       <td id="T_2ebb1_row5_col6" class="data row5 col6" >12.900000</td>
#       <td id="T_2ebb1_row5_col7" class="data row5 col7" >1.640122</td>
#       <td id="T_2ebb1_row5_col8" class="data row5 col8" >15.500000</td>
#       <td id="T_2ebb1_row5_col9" class="data row5 col9" >1.565248</td>
#     </tr>
#     <tr>
#       <th id="T_2ebb1_level0_row6" class="row_heading level0 row6" >MULT:Wine</th>
#       <td id="T_2ebb1_row6_col0" class="data row6 col0" >11.500000</td>
#       <td id="T_2ebb1_row6_col1" class="data row6 col1" >2.061553</td>
#       <td id="T_2ebb1_row6_col2" class="data row6 col2" >24.000000</td>
#       <td id="T_2ebb1_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_2ebb1_row6_col4" class="data row6 col4" >5.100000</td>
#       <td id="T_2ebb1_row6_col5" class="data row6 col5" >2.385372</td>
#       <td id="T_2ebb1_row6_col6" class="data row6 col6" >13.600000</td>
#       <td id="T_2ebb1_row6_col7" class="data row6 col7" >0.800000</td>
#       <td id="T_2ebb1_row6_col8" class="data row6 col8" >6.200000</td>
#       <td id="T_2ebb1_row6_col9" class="data row6 col9" >1.166190</td>
#     </tr>
#     <tr>
#       <th id="T_2ebb1_level0_row7" class="row_heading level0 row7" >MULT:Zoo</th>
#       <td id="T_2ebb1_row7_col0" class="data row7 col0" >12.000000</td>
#       <td id="T_2ebb1_row7_col1" class="data row7 col1" >1.949359</td>
#       <td id="T_2ebb1_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_2ebb1_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_2ebb1_row7_col4" class="data row7
# <style type="text/css">
# #T_cfbfb_row0_col4, #T_cfbfb_row1_col4, #T_cfbfb_row2_col4, #T_cfbfb_row3_col4, #T_cfbfb_row4_col4, #T_cfbfb_row5_col8, #T_cfbfb_row6_col4, #T_cfbfb_row7_col8, #T_cfbfb_row8_col4, #T_cfbfb_row9_col4, #T_cfbfb_row10_col4, #T_cfbfb_row11_col4, #T_cfbfb_row12_col4, #T_cfbfb_row13_col4, #T_cfbfb_row16_col4 {
#   background-color: #FF6961;
# }
# #T_cfbfb_row0_col6, #T_cfbfb_row1_col8, #T_cfbfb_row2_col2, #T_cfbfb_row3_col2, #T_cfbfb_row4_col2, #T_cfbfb_row5_col2, #T_cfbfb_row6_col2, #T_cfbfb_row7_col6, #T_cfbfb_row8_col6, #T_cfbfb_row9_col0, #T_cfbfb_row10_col6, #T_cfbfb_row11_col8, #T_cfbfb_row12_col6, #T_cfbfb_row13_col0, #T_cfbfb_row16_col2 {
#   background-color: #9CC95C;
# }
# </style>
# <table id="T_cfbfb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfbfb_level0_col0" class="col_heading level0 col0" >GDT leaf_node_num_mean</th>
#       <th id="T_cfbfb_level0_col1" class="col_heading level0 col1" >GDT leaf_node_num_std</th>
#       <th id="T_cfbfb_level0_col2" class="col_heading level0 col2" >DNDT leaf_node_num_mean</th>
#       <th id="T_cfbfb_level0_col3" class="col_heading level0 col3" >DNDT leaf_node_num_std</th>
#       <th id="T_cfbfb_level0_col4" class="col_heading level0 col4" >GeneticTree leaf_node_num_mean</th>
#       <th id="T_cfbfb_level0_col5" class="col_heading level0 col5" >GeneticTree leaf_node_num_std</th>
#       <th id="T_cfbfb_level0_col6" class="col_heading level0 col6" >DL85 leaf_node_num_mean</th>
#       <th id="T_cfbfb_level0_col7" class="col_heading level0 col7" >DL85 leaf_node_num_std</th>
#       <th id="T_cfbfb_level0_col8" class="col_heading level0 col8" >sklearn leaf_node_num_mean</th>
#       <th id="T_cfbfb_level0_col9" class="col_heading level0 col9" >sklearn leaf_node_num_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfbfb_level0_row0" class="row_heading level0 row0" >MULT:Iris</th>
#       <td id="T_cfbfb_row0_col0" class="data row0 col0" >7.700000</td>
#       <td id="T_cfbfb_row0_col1" class="data row0 col1" >1.268858</td>
#       <td id="T_cfbfb_row0_col2" class="data row0 col2" >16.000000</td>
#       <td id="T_cfbfb_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_cfbfb_row0_col4" class="data row0 col4" >5.000000</td>
#       <td id="T_cfbfb_row0_col5" class="data row0 col5" >1.549193</td>
#       <td id="T_cfbfb_row0_col6" class="data row0 col6" >29.200000</td>
#       <td id="T_cfbfb_row0_col7" class="data row0 col7" >1.400000</td>
#       <td id="T_cfbfb_row0_col8" class="data row0 col8" >5.200000</td>
#       <td id="T_cfbfb_row0_col9" class="data row0 col9" >0.748331</td>
#     </tr>
#     <tr>
#       <th id="T_cfbfb_level0_row1" class="row_heading level0 row1" >MULT:Balance Scale</th>
#       <td id="T_cfbfb_row1_col0" class="data row1 col0" >59.800000</td>
#       <td id="T_cfbfb_row1_col1" class="data row1 col1" >13.548432</td>
#       <td id="T_cfbfb_row1_col2" class="data row1 col2" >16.000000</td>
#       <td id="T_cfbfb_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_cfbfb_row1_col4" class="data row1 col4" >13.200000</td>
#       <td id="T_cfbfb_row1_col5" class="data row1 col5" >5.653318</td>
#       <td id="T_cfbfb_row1_col6" class="data row1 col6" >31.000000</td>
#       <td id="T_cfbfb_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_cfbfb_row1_col8" class="data row1 col8" >81.100000</td>
#       <td id="T_cfbfb_row1_col9" class="data row1 col9" >4.459821</td>
#     </tr>
#     <tr>
#       <th id="T_cfbfb_level0_row2" class="row_heading level0 row2" >MULT:Car</th>
#       <td id="T_cfbfb_row2_col0" class="data row2 col0" >24.000000</td>
#       <td id="T_cfbfb_row2_col1" class="data row2 col1" >6.782330</td>
#       <td id="T_cfbfb_row2_col2" class="data row2 col2" >64.000000</td>
#       <td id="T_cfbfb_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_cfbfb_row2_col4" class="data row2 col4" >16.800000</td>
#       <td id="T_cfbfb_row2_col5" class="data row2 col5" >10.675205</td>
#       <td id="T_cfbfb_row2_col6" class="data row2 col6" >29.800000</td>
#       <td id="T_cfbfb_row2_col7" class="data row2 col7" >0.979796</td>
#       <td id="T_cfbfb_row2_col8" class="data row2 col8" >29.000000</td>
#       <td id="T_cfbfb_row2_col9" class="data row2 col9" >6.511528</td>
#     </tr>
#     <tr>
#       <th id="T_cfbfb_level0_row3" class="row_heading level0 row3" >MULT:Glass</th>
#       <td id="T_cfbfb_row3_col0" class="data row3 col0" >28.900000</td>
#       <td id="T_cfbfb_row3_col1" class="data row3 col1" >5.503635</td>
#       <td id="T_cfbfb_row3_col2" class="data row3 col2" >512.000000</td>
#       <td id="T_cfbfb_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_cfbfb_row3_col4" class="data row3 col4" >11.400000</td>
#       <td id="T_cfbfb_row3_col5" class="data row3 col5" >5.765414</td>
#       <td id="T_cfbfb_row3_col6" class="data row3 col6" >30.600000</td>
#       <td id="T_cfbfb_row3_col7" class="data row3 col7" >0.800000</td>
#       <td id="T_cfbfb_row3_col8" class="data row3 col8" >34.500000</td>
#       <td id="T_cfbfb_row3_col9" class="data row3 col9" >3.170173</td>
#     </tr>
#     <tr>
#       <th id="T_cfbfb_level0_row4" class="row_heading level0 row4" >MULT:Contraceptive</th>
#       <td id="T_cfbfb_row4_col0" class="data row4 col0" >20.800000</td>
#       <td id="T_cfbfb_row4_col1" class="data row4 col1" >5.741080</td>
#       <td id="T_cfbfb_row4_col2" class="data row4 col2" >512.000000</td>
#       <td id="T_cfbfb_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_cfbfb_row4_col4" class="data row4 col4" >6.900000</td>
#       <td id="T_cfbfb_row4_col5" class="data row4 col5" >1.920937</td>
#       <td id="T_cfbfb_row4_col6" class="data row4 col6" >30.000000</td>
#       <td id="T_cfbfb_row4_col7" class="data row4 col7" >1.341641</td>
#       <td id="T_cfbfb_row4_col8" class="data row4 col8" >24.800000</td>
#       <td id="T_cfbfb_row4_col9" class="data row4 col9" >3.572114</td>
#     </tr>
#     <tr>
#       <th id="T_cfbfb_level0_row5" class="row_heading level0 row5" >MULT:Solar Flare</th>
#       <td id="T_cfbfb_row5_col0" class="data row5 col0" >25.400000</td>
#       <td id="T_cfbfb_row5_col1" class="data row5 col1" >4.651881</td>
#       <td id="T_cfbfb_row5_col2" class="data row5 col2" >1024.000000</td>
#       <td id="T_cfbfb_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_cfbfb_row5_col4" class="data row5 col4" >19.700000</td>
#       <td id="T_cfbfb_row5_col5" class="data row5 col5" >10.705606</td>
#       <td id="T_cfbfb_row5_col6" class="data row5 col6" >26.800000</td>
#       <td id="T_cfbfb_row5_col7" class="data row5 col7" >3.280244</td>
#       <td id="T_cfbfb_row5_col8" class="data row5 col8" >16.500000</td>
#       <td id="T_cfbfb_row5_col9" class="data row5 col9" >1.565248</td>
#     </tr>
#     <tr>
#       <th id="T_cfbfb_level0_row6" class="row_heading level0 row6" >MULT:Wine</th>
#       <td id="T_cfbfb_row6_col0" class="data row6 col0" >12.500000</td>
#       <td id="T_cfbfb_row6_col1" class="data row6 col1" >2.061553</td>
#       <td id="T_cfbfb_row6_col2" class="data row6 col2" >4096.000000</td>
#       <td id="T_cfbfb_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_cfbfb_row6_col4" class="data row6 col4" >6.100000</td>
#       <td id="T_cfbfb_row6_col5" class="data row6 col5" >2.385372</td>
#       <td id="T_cfbfb_row6_col6" class="data row6 col6" >28.200000</td>
#       <td id="T_cfbfb_row6_col7" class="data row6 col7" >1.600000</td>
#       <td id="T_cfbfb_row6_col8" class="data row6 col8" >7.200000</td>
#       <td id="T_cfbfb_row6_col9" class="data row6 col9" >1.166190</td>
#     </tr>
#     <tr>
#       <th id="T_cfbfb_level0_row7" class="row_heading level0 row7" >MULT:Zoo</th>
#       <td id="T_cfbfb_row7_col0" class="data row7 col0" >13.000000</td>
#       <td id="T_cfbfb_row7_col1" class="data row7 col1" >1.949359</td>
#       <td id="T_cfbfb_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_cfbfb_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_cfbfb_row7_col4" class="data row7 col4" >16.800000</td>
#       <td

# %%
from numba import cuda 
if config['computation']['use_gpu']:
    device = cuda.get_current_device()
    device.reset()
